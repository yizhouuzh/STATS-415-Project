# %%
import numpy as np
import pandas as pd
import difflib
import Levenshtein
import xgboost as xgb
import sklearn
from sklearn.model_selection import train_test_split
import scipy.stats

# %%
#### This function find the wildtype of a group of enzymes by 
#### taking the most frequent amino acids as the wildtype.
#### Return: the sequence of wildtype with the same formula 
#### as the sequence in training_data.
def get_wt(X):
    length = {}
    for i in X:
        l = len(i)
        if l not in length:
            length[l] = 1
        else:
            length[l] += 1
    wt_len = max(length, key=length.get)
    wild_type = []
    for i in range(wt_len):
        lt = []
        for j in X:
            if (len(j)>i):
                lt.append(j[i])
        wild_type.append(get_most(lt))
    return ''.join(wild_type)
#### This function finds the wildtype based on the sample have the 
#### smallest sum of Levenshtein distance on its amino acid sequence
#### It returns the index of the wildtype in the group.
def get_wt_sup(X):
    l = len(X)
    lenlist = []
    for i in range(l):
        s = 0
        for j in range(l):
            s += Levenshtein.distance(X[i],X[j])
        lenlist.append(s)
    lenlist = np.array(lenlist)
    return np.argmin(lenlist)

#### This function returns the key with maximum value in a dictionary.
def get_most(X):
    c_max = 0
    n = X[0]
    for i in X:
        c = X.count(i)
        if c > c_max:
            n = i
            c_max = c
    return n

# %%
#### We use difflib.ndiff from package difflib to
#### find the difference between two strings. 
#### These two functions will find the mutation type 
#### from the result originated by difflib.ndiff
#### And transform it to a more readable form
#### Returns: a dictionary specifies the mutation type
#### and its amount in a sequence.
def find_mutation(x,y):
    if (len(x)!=len(y)):
        d = find_mut(x,y)
        if (len(d)==1):
            return d
    m = int(len(x)/2)
    d1 = find_mut(x[0:m],y[0:m])
    d2 = find_mut(x[m:],y[m:])
    d3 = {**d1,**d2}
    return d3
def find_mut(x,y):    
    mutation = {}
    tmp = ''
    has_minus = False
    for i, j in enumerate(difflib.ndiff(x,y)):
        if ((j[0]=="-") and has_minus==False):
            has_minus = True
            tmp = j[0]+j[2]
        elif ((j[0]=="+")and has_minus):
            has_minus = False
            tmp+=j[0]+j[2]
            if tmp not in mutation:
                mutation[tmp]=1
            else:
                mutation[tmp]+=1
            tmp = ''
        elif ((j[0]!="+")and(j[0]!="-")and has_minus):
            has_minus = False
            if tmp not in mutation:
                mutation[tmp]=1
            else:
                mutation[tmp]+=1
            tmp = ''
        elif ((j[0]=="-")and has_minus):
            has_minus = False
            if tmp not in mutation:
                mutation[tmp]=1
            else:
                mutation[tmp]+=1
            tmp = j[0]+j[2]
    return mutation

# %%
#### This function finds the positions of mutations, 
#### which helps us find the neighbouring acids around the mutation.
def find_mut_pst(x,y):    
    mutation = []
    has_minus = False
    for i, j in enumerate(difflib.ndiff(x,y)):
        if ((j[0]=="-") and has_minus==False):
            has_minus = True
        elif ((j[0]=="+")and has_minus):
            has_minus = False
            mutation.append(i)
        elif ((j[0]!="+")and(j[0]!="-")and has_minus):
            has_minus = False
            mutation.append(i)
        elif ((j[0]=="-")and has_minus):
            has_minus = False
            mutation.append(i)
    return np.array(mutation)
#### This function find the count of each amino acid in the neighbor of 
def get_nba(x,wt,nbl = 20):
    l = len(x)
    lwt = len(wt)
    freq = {}
    for i in range(l):
        left = max(x[i]-20, 0)
        right = min(lwt, x[i]+20)
        for i in range(left,right):
            ca = wt[i]
            if ca in freq:
                freq[ca]+=1/l
            elif ca not in freq:
                freq[ca]=1/l
    return freq

# %%
test_data = pd.read_csv('test.csv')
cdata = pd.read_csv('grouped_sample_no_pH_one_muta.csv')
seq = test_data['protein_sequence']

# %%
#### Generating the wild type of test samples.
test_wt = get_wt(seq)

# %%
#### Generating the data frame of mutation occurences of test data.

df = pd.DataFrame()
for i in seq:
    freq = find_mutation(test_wt, i)
    dff = pd.DataFrame(freq,index=[1])
    df = pd.concat([df,dff],ignore_index = True)
dm = df.fillna(0)

# %%
#### Generating the data frame of neighboring amino acids occurences of test data.

df2 = pd.DataFrame()
for i in seq:
    x = find_mut_pst(test_wt, i)
    freq = get_nba(x, test_wt)
    dff = pd.DataFrame(freq, index=[1])
    df2 = pd.concat([df2,dff], ignore_index = True)
dm2 = df2.fillna(0)

# %%
test_design=pd.concat([dm,dm2],axis = 1,ignore_index=True)

# %%
test_design.to_csv('test_design.csv')

# %%
#### Generating the design matrix of training data

group_num = max(cdata['group'])
X1 = pd.DataFrame()
X2 = pd.DataFrame()
y = np.array([])
for i in range(0,group_num+1):
    group_data = cdata[cdata['group']==i]
    g_seq = group_data['protein_sequence']
    g_seq = np.array(g_seq)
    g_y = group_data['tm']
    g_y = np.array(g_y)
    wt_index = get_wt_sup(g_seq)
    g_y = g_y - g_y[wt_index]
    y = np.append(y, g_y)
    wt = g_seq[wt_index]
    for i in g_seq:
        freq = find_mutation(wt,i)
        df = pd.DataFrame(freq,index=[1])
        X1 = pd.concat([X1,df],ignore_index = True)
        x = find_mut_pst(wt, i)
        freq2 = get_nba(x, wt)
        dff = pd.DataFrame(freq2, index=[1])
        X2 = pd.concat([X2,dff], ignore_index = True)
X1 = X1.fillna(0)
X2 = X2.fillna(0)
train_X = pd.concat([X1,X2],axis = 1, ignore_index = True)
train_y = y

# %%
####Ensuring design matrix(features) of training and test data have the same size.
check = pd.concat([X1, dm],ignore_index=True).fillna(0)
dim1 = len(y)
dim2 = cdata.shape[0]
X1 = check.iloc[0:dim1]
dm = check.iloc[dim1:(dim1+dim2)]
check2 = pd.concat([X2, dm2],ignore_index=True).fillna(0)
X2 = check2.iloc[0:dim1]
dm2 = check2.iloc[dim1:(dim1+dim2)]

# %%
####XGBoost Upgraded (Model 2)

xgb_parms = { 
    'max_depth':5, 
    'learning_rate':0.001, 
    'subsample':0.6,
    'colsample_bytree':0.3, 
    'eval_metric':'rmse',
    'objective':'reg:squarederror',
    'random_state':123
}
X_train, X_valid, y_train, y_valid = train_test_split(train_X, y, test_size=0.1, random_state=123)
model = xgb
dtrain = xgb.DMatrix(data=X_train, label=y_train)
dvalid = xgb.DMatrix(data=X_valid, label=y_valid)
dtest = xgb.DMatrix(data=test_X)

# %%
m2 = xgb.train(xgb_parms, dtrain=dtrain,evals=[(dtrain,"train"),(dvalid, "valid")],
                 num_boost_round=10000,
                 early_stopping_rounds = 100,
                 verbose_eval = 100)
# Out:
# [0]	train-rmse:12.17984	valid-rmse:12.43337
# [100]	train-rmse:11.88096	valid-rmse:12.15961
# [200]	train-rmse:11.61433	valid-rmse:11.90944
# [300]	train-rmse:11.36296	valid-rmse:11.67640
# [400]	train-rmse:11.13389	valid-rmse:11.46623
# [500]	train-rmse:10.92103	valid-rmse:11.26987
# [600]	train-rmse:10.72688	valid-rmse:11.09278
# [700]	train-rmse:10.54345	valid-rmse:10.92550
# [800]	train-rmse:10.38090	valid-rmse:10.77967
# [900]	train-rmse:10.23631	valid-rmse:10.64478
# [1000]	train-rmse:10.09328	valid-rmse:10.51771
# [1100]	train-rmse:9.96293	valid-rmse:10.40306
# [1200]	train-rmse:9.84414	valid-rmse:10.29503
# [1300]	train-rmse:9.73303	valid-rmse:10.19598
# [1400]	train-rmse:9.62945	valid-rmse:10.10379
# [1500]	train-rmse:9.53482	valid-rmse:10.02506
# [1600]	train-rmse:9.44661	valid-rmse:9.94923
# [1700]	train-rmse:9.36949	valid-rmse:9.88407
# [1800]	train-rmse:9.29581	valid-rmse:9.81994
# [1900]	train-rmse:9.22547	valid-rmse:9.76049
# [2000]	train-rmse:9.15941	valid-rmse:9.70514
# [2100]	train-rmse:9.09754	valid-rmse:9.65448
# [2200]	train-rmse:9.04420	valid-rmse:9.61073
# [2300]	train-rmse:8.98992	valid-rmse:9.56577
# [2400]	train-rmse:8.93982	valid-rmse:9.52672
# [2500]	train-rmse:8.89083	valid-rmse:9.48677
# [2600]	train-rmse:8.84609	valid-rmse:9.45010
# [2700]	train-rmse:8.80192	valid-rmse:9.41572
# [2800]	train-rmse:8.76025	valid-rmse:9.38154
# [2900]	train-rmse:8.71965	valid-rmse:9.35122
# [3000]	train-rmse:8.68172	valid-rmse:9.32289
# [3100]	train-rmse:8.64620	valid-rmse:9.29614
# [3200]	train-rmse:8.61141	valid-rmse:9.27168
# [3300]	train-rmse:8.57888	valid-rmse:9.24877
# [3400]	train-rmse:8.54870	valid-rmse:9.22872
# [3500]	train-rmse:8.51854	valid-rmse:9.20555
# [3600]	train-rmse:8.48845	valid-rmse:9.18479
# [3700]	train-rmse:8.45921	valid-rmse:9.16455
# [3800]	train-rmse:8.43211	valid-rmse:9.14519
# [3900]	train-rmse:8.40699	valid-rmse:9.12823
# [4000]	train-rmse:8.38141	valid-rmse:9.10909
# [4100]	train-rmse:8.35628	valid-rmse:9.09300
# [4200]	train-rmse:8.33162	valid-rmse:9.07625
# [4300]	train-rmse:8.30789	valid-rmse:9.06065
# [4400]	train-rmse:8.28469	valid-rmse:9.04675
# [4500]	train-rmse:8.26377	valid-rmse:9.03346
# [4600]	train-rmse:8.24340	valid-rmse:9.02097
# [4700]	train-rmse:8.22298	valid-rmse:9.00893
# [4800]	train-rmse:8.20284	valid-rmse:8.99615
# [4900]	train-rmse:8.18346	valid-rmse:8.98471
# [5000]	train-rmse:8.16458	valid-rmse:8.97461
# [5100]	train-rmse:8.14581	valid-rmse:8.96426
# [5200]	train-rmse:8.12712	valid-rmse:8.95445
# [5300]	train-rmse:8.10964	valid-rmse:8.94656
# [5400]	train-rmse:8.09293	valid-rmse:8.93831
# [5500]	train-rmse:8.07682	valid-rmse:8.93051
# [5600]	train-rmse:8.06009	valid-rmse:8.92161
# [5700]	train-rmse:8.04441	valid-rmse:8.91465
# [5800]	train-rmse:8.02827	valid-rmse:8.90578
# [5900]	train-rmse:8.01311	valid-rmse:8.89789
# [6000]	train-rmse:7.99731	valid-rmse:8.89249
# [6100]	train-rmse:7.98233	valid-rmse:8.88624
# [6200]	train-rmse:7.96749	valid-rmse:8.87847
# [6300]	train-rmse:7.95249	valid-rmse:8.87118
# [6400]	train-rmse:7.93891	valid-rmse:8.86391
# [6500]	train-rmse:7.92591	valid-rmse:8.85716
# [6600]	train-rmse:7.91155	valid-rmse:8.85092
# [6700]	train-rmse:7.89846	valid-rmse:8.84505
# [6800]	train-rmse:7.88518	valid-rmse:8.83818
# [6900]	train-rmse:7.87174	valid-rmse:8.83299
# [7000]	train-rmse:7.85903	valid-rmse:8.82691
# [7100]	train-rmse:7.84698	valid-rmse:8.82137
# [7200]	train-rmse:7.83500	valid-rmse:8.81739
# [7300]	train-rmse:7.82286	valid-rmse:8.81441
# [7400]	train-rmse:7.81071	valid-rmse:8.81043
# [7500]	train-rmse:7.79938	valid-rmse:8.80482
# [7600]	train-rmse:7.78829	valid-rmse:8.80045
# [7700]	train-rmse:7.77621	valid-rmse:8.79496
# [7800]	train-rmse:7.76465	valid-rmse:8.78986
# [7900]	train-rmse:7.75402	valid-rmse:8.78539
# [8000]	train-rmse:7.74291	valid-rmse:8.78268
# [8100]	train-rmse:7.73221	valid-rmse:8.77804
# [8200]	train-rmse:7.72219	valid-rmse:8.77339
# [8300]	train-rmse:7.71116	valid-rmse:8.76879
# [8400]	train-rmse:7.70109	valid-rmse:8.76494
# [8500]	train-rmse:7.69028	valid-rmse:8.76189
# [8600]	train-rmse:7.68013	valid-rmse:8.75931
# [8700]	train-rmse:7.67003	valid-rmse:8.75719
# [8800]	train-rmse:7.65978	valid-rmse:8.75416
# [8900]	train-rmse:7.64964	valid-rmse:8.75126
# [9000]	train-rmse:7.64005	valid-rmse:8.74854
# [9100]	train-rmse:7.62974	valid-rmse:8.74543
# [9200]	train-rmse:7.61987	valid-rmse:8.74342
# [9300]	train-rmse:7.61063	valid-rmse:8.74174
# [9400]	train-rmse:7.60127	valid-rmse:8.73872
# [9500]	train-rmse:7.59240	valid-rmse:8.73544
# [9600]	train-rmse:7.58301	valid-rmse:8.73208
# [9700]	train-rmse:7.57444	valid-rmse:8.72873
# [9800]	train-rmse:7.56674	valid-rmse:8.72674
# [9900]	train-rmse:7.55809	valid-rmse:8.72495
# [9999]	train-rmse:7.54994	valid-rmse:8.72394

# %%
valid_pred = m2.predict(dvalid)
scipy.stats.spearmanr(valid_pred, y_valid)
# Out:
# SpearmanrResult(correlation=0.6486030622950832, pvalue=2.7605737795994982e-53)

# %%
####Grid search on the XGBoost model.

max_len = [3,4,5]
lr = [0.001,0.005,0.01]
subs = [0.5,0.6,0.7]
cols = [0.2,0.25,0.3]
rmax= 0
index = [3,0.001,0.5,0.15]
for i in max_len:
    for j in lr:
        for k in subs:
            for l in cols:
                xgb_parms = { 
                    'max_depth':i, 
                    'learning_rate':j, 
                    'subsample':k,
                    'colsample_bytree':l, 
                    'eval_metric':'rmse',
                    'objective':'reg:squarederror',
                    'random_state':123,
                    "reg_lambda":0.1
                }
                X_train, X_valid, y_train, y_valid = train_test_split(train_X, train_y, test_size=0.1, random_state=123)
                model = xgb
                dtrain = xgb.DMatrix(data=X_train, label=y_train)
                dvalid = xgb.DMatrix(data=X_valid, label=y_valid)

                m2 = xgb.train(xgb_parms, dtrain=dtrain,evals=[(dtrain,"train"),(dvalid, "valid")],
                                 num_boost_round=5000,
                                 early_stopping_rounds = 100,
                                 verbose_eval = 100)

                pred=m2.predict(dvalid)
                result = scipy.stats.spearmanr(pred, y_valid)[0]
                print(i,j,k,l)
                print(result)
                if result > rmax:
                    index[0]=i
                    index[1]=j
                    index[2]=k
                    index[3]=l
                    rmax = result
# Out:
# [0]	train-rmse:12.18183	valid-rmse:12.43504
# [100]	train-rmse:12.01955	valid-rmse:12.27673
# [200]	train-rmse:11.85986	valid-rmse:12.12117
# [300]	train-rmse:11.71437	valid-rmse:11.97871
# [400]	train-rmse:11.58127	valid-rmse:11.84785
# [500]	train-rmse:11.44999	valid-rmse:11.71885
# [600]	train-rmse:11.33185	valid-rmse:11.60310
# [700]	train-rmse:11.21754	valid-rmse:11.49582
# [800]	train-rmse:11.10816	valid-rmse:11.38886
# [900]	train-rmse:11.00998	valid-rmse:11.29090
# [1000]	train-rmse:10.91109	valid-rmse:11.19879
# [1100]	train-rmse:10.81930	valid-rmse:11.10887
# [1200]	train-rmse:10.73679	valid-rmse:11.02982
# [1300]	train-rmse:10.65405	valid-rmse:10.94772
# [1400]	train-rmse:10.57731	valid-rmse:10.87148
# [1500]	train-rmse:10.50348	valid-rmse:10.80059
# [1600]	train-rmse:10.43289	valid-rmse:10.73127
# [1700]	train-rmse:10.36520	valid-rmse:10.66764
# [1800]	train-rmse:10.30223	valid-rmse:10.60637
# [1900]	train-rmse:10.24343	valid-rmse:10.55022
# [2000]	train-rmse:10.18501	valid-rmse:10.49395
# [2100]	train-rmse:10.13232	valid-rmse:10.44353
# [2200]	train-rmse:10.08164	valid-rmse:10.39461
# [2300]	train-rmse:10.03103	valid-rmse:10.34512
# [2400]	train-rmse:9.98337	valid-rmse:10.30020
# [2500]	train-rmse:9.93589	valid-rmse:10.25563
# [2600]	train-rmse:9.89216	valid-rmse:10.21610
# [2700]	train-rmse:9.84939	valid-rmse:10.17538
# [2800]	train-rmse:9.80956	valid-rmse:10.13785
# [2900]	train-rmse:9.77009	valid-rmse:10.09858
# [3000]	train-rmse:9.73322	valid-rmse:10.06483
# [3100]	train-rmse:9.69647	valid-rmse:10.03139
# [3200]	train-rmse:9.66195	valid-rmse:9.99657
# [3300]	train-rmse:9.62895	valid-rmse:9.96474
# [3400]	train-rmse:9.59774	valid-rmse:9.93620
# [3500]	train-rmse:9.56525	valid-rmse:9.90489
# [3600]	train-rmse:9.53446	valid-rmse:9.87636
# [3700]	train-rmse:9.50658	valid-rmse:9.84982
# [3800]	train-rmse:9.47764	valid-rmse:9.82300
# [3900]	train-rmse:9.45045	valid-rmse:9.79818
# [4000]	train-rmse:9.42444	valid-rmse:9.77595
# [4100]	train-rmse:9.39726	valid-rmse:9.75252
# [4200]	train-rmse:9.37165	valid-rmse:9.72989
# [4300]	train-rmse:9.34648	valid-rmse:9.70835
# [4400]	train-rmse:9.32176	valid-rmse:9.68602
# [4500]	train-rmse:9.29850	valid-rmse:9.66558
# [4600]	train-rmse:9.27586	valid-rmse:9.64525
# [4700]	train-rmse:9.25248	valid-rmse:9.62508
# [4800]	train-rmse:9.22904	valid-rmse:9.60309
# [4900]	train-rmse:9.20740	valid-rmse:9.58513
# [4999]	train-rmse:9.18669	valid-rmse:9.56759
# 3 0.001 0.5 0.2
# 0.6105093573296614
# [0]	train-rmse:12.18137	valid-rmse:12.43400
# [100]	train-rmse:12.00602	valid-rmse:12.26233
# [200]	train-rmse:11.83571	valid-rmse:12.09840
# [300]	train-rmse:11.68029	valid-rmse:11.94644
# [400]	train-rmse:11.54119	valid-rmse:11.80789
# [500]	train-rmse:11.40317	valid-rmse:11.67240
# [600]	train-rmse:11.27966	valid-rmse:11.55049
# [700]	train-rmse:11.16013	valid-rmse:11.43613
# [800]	train-rmse:11.04884	valid-rmse:11.32395
# [900]	train-rmse:10.94617	valid-rmse:11.22175
# [1000]	train-rmse:10.84493	valid-rmse:11.12466
# [1100]	train-rmse:10.75091	valid-rmse:11.03451
# [1200]	train-rmse:10.66490	valid-rmse:10.95229
# [1300]	train-rmse:10.58301	valid-rmse:10.87199
# [1400]	train-rmse:10.50697	valid-rmse:10.79739
# [1500]	train-rmse:10.43422	valid-rmse:10.72829
# [1600]	train-rmse:10.36533	valid-rmse:10.66135
# [1700]	train-rmse:10.29920	valid-rmse:10.59826
# [1800]	train-rmse:10.23573	valid-rmse:10.53625
# [1900]	train-rmse:10.17707	valid-rmse:10.47954
# [2000]	train-rmse:10.11919	valid-rmse:10.42379
# [2100]	train-rmse:10.06554	valid-rmse:10.37331
# [2200]	train-rmse:10.01482	valid-rmse:10.32395
# [2300]	train-rmse:9.96675	valid-rmse:10.27758
# [2400]	train-rmse:9.91983	valid-rmse:10.23394
# [2500]	train-rmse:9.87478	valid-rmse:10.19014
# [2600]	train-rmse:9.83138	valid-rmse:10.14827
# [2700]	train-rmse:9.78912	valid-rmse:10.10789
# [2800]	train-rmse:9.75098	valid-rmse:10.07122
# [2900]	train-rmse:9.71285	valid-rmse:10.03415
# [3000]	train-rmse:9.67673	valid-rmse:9.99899
# [3100]	train-rmse:9.64027	valid-rmse:9.96523
# [3200]	train-rmse:9.60580	valid-rmse:9.93051
# [3300]	train-rmse:9.57307	valid-rmse:9.89984
# [3400]	train-rmse:9.54240	valid-rmse:9.87257
# [3500]	train-rmse:9.51090	valid-rmse:9.84285
# [3600]	train-rmse:9.48068	valid-rmse:9.81506
# [3700]	train-rmse:9.45269	valid-rmse:9.78926
# [3800]	train-rmse:9.42317	valid-rmse:9.76208
# [3900]	train-rmse:9.39640	valid-rmse:9.73762
# [4000]	train-rmse:9.37110	valid-rmse:9.71539
# [4100]	train-rmse:9.34467	valid-rmse:9.69093
# [4200]	train-rmse:9.31921	valid-rmse:9.66764
# [4300]	train-rmse:9.29425	valid-rmse:9.64533
# [4400]	train-rmse:9.26991	valid-rmse:9.62249
# [4500]	train-rmse:9.24640	valid-rmse:9.60130
# [4600]	train-rmse:9.22444	valid-rmse:9.58304
# [4700]	train-rmse:9.20128	valid-rmse:9.56225
# [4800]	train-rmse:9.17833	valid-rmse:9.54121
# [4900]	train-rmse:9.15792	valid-rmse:9.52405
# [4999]	train-rmse:9.13762	valid-rmse:9.50798
# 3 0.001 0.5 0.25
# 0.6143175944840494
# [0]	train-rmse:12.18133	valid-rmse:12.43396
# [100]	train-rmse:11.99550	valid-rmse:12.25521
# [200]	train-rmse:11.81885	valid-rmse:12.08277
# [300]	train-rmse:11.65642	valid-rmse:11.92607
# [400]	train-rmse:11.50783	valid-rmse:11.77920
# [500]	train-rmse:11.36581	valid-rmse:11.63727
# [600]	train-rmse:11.23668	valid-rmse:11.50826
# [700]	train-rmse:11.11398	valid-rmse:11.39019
# [800]	train-rmse:11.00147	valid-rmse:11.27560
# [900]	train-rmse:10.89967	valid-rmse:11.17304
# [1000]	train-rmse:10.79658	valid-rmse:11.07458
# [1100]	train-rmse:10.70224	valid-rmse:10.98243
# [1200]	train-rmse:10.61590	valid-rmse:10.90055
# [1300]	train-rmse:10.53195	valid-rmse:10.82024
# [1400]	train-rmse:10.45349	valid-rmse:10.74302
# [1500]	train-rmse:10.38071	valid-rmse:10.67375
# [1600]	train-rmse:10.31279	valid-rmse:10.60751
# [1700]	train-rmse:10.24754	valid-rmse:10.54442
# [1800]	train-rmse:10.18499	valid-rmse:10.48244
# [1900]	train-rmse:10.12733	valid-rmse:10.42667
# [2000]	train-rmse:10.07124	valid-rmse:10.37182
# [2100]	train-rmse:10.01875	valid-rmse:10.32126
# [2200]	train-rmse:9.96881	valid-rmse:10.27319
# [2300]	train-rmse:9.92127	valid-rmse:10.22669
# [2400]	train-rmse:9.87540	valid-rmse:10.18179
# [2500]	train-rmse:9.83025	valid-rmse:10.13756
# [2600]	train-rmse:9.78793	valid-rmse:10.09493
# [2700]	train-rmse:9.74618	valid-rmse:10.05537
# [2800]	train-rmse:9.70858	valid-rmse:10.01761
# [2900]	train-rmse:9.67030	valid-rmse:9.98157
# [3000]	train-rmse:9.63439	valid-rmse:9.94805
# [3100]	train-rmse:9.59877	valid-rmse:9.91665
# [3200]	train-rmse:9.56407	valid-rmse:9.88460
# [3300]	train-rmse:9.53112	valid-rmse:9.85427
# [3400]	train-rmse:9.50088	valid-rmse:9.82853
# [3500]	train-rmse:9.47152	valid-rmse:9.80054
# [3600]	train-rmse:9.44177	valid-rmse:9.77281
# [3700]	train-rmse:9.41337	valid-rmse:9.74631
# [3800]	train-rmse:9.38426	valid-rmse:9.72014
# [3900]	train-rmse:9.35752	valid-rmse:9.69681
# [4000]	train-rmse:9.33152	valid-rmse:9.67418
# [4100]	train-rmse:9.30542	valid-rmse:9.65243
# [4200]	train-rmse:9.28087	valid-rmse:9.63007
# [4300]	train-rmse:9.25618	valid-rmse:9.60707
# [4400]	train-rmse:9.23223	valid-rmse:9.58506
# [4500]	train-rmse:9.20894	valid-rmse:9.56443
# [4600]	train-rmse:9.18726	valid-rmse:9.54752
# [4700]	train-rmse:9.16431	valid-rmse:9.52740
# [4800]	train-rmse:9.14122	valid-rmse:9.50515
# [4900]	train-rmse:9.12078	valid-rmse:9.48818
# [4999]	train-rmse:9.10046	valid-rmse:9.47259
# 3 0.001 0.5 0.3
# 0.6125396142951657
# [0]	train-rmse:12.18185	valid-rmse:12.43506
# [100]	train-rmse:12.01682	valid-rmse:12.27291
# [200]	train-rmse:11.85689	valid-rmse:12.11758
# [300]	train-rmse:11.71000	valid-rmse:11.97392
# [400]	train-rmse:11.57584	valid-rmse:11.84288
# [500]	train-rmse:11.44434	valid-rmse:11.71661
# [600]	train-rmse:11.32421	valid-rmse:11.60075
# [700]	train-rmse:11.20804	valid-rmse:11.49071
# [800]	train-rmse:11.09826	valid-rmse:11.38472
# [900]	train-rmse:11.00018	valid-rmse:11.28782
# [1000]	train-rmse:10.90168	valid-rmse:11.19708
# [1100]	train-rmse:10.80910	valid-rmse:11.10817
# [1200]	train-rmse:10.72595	valid-rmse:11.02821
# [1300]	train-rmse:10.64289	valid-rmse:10.94785
# [1400]	train-rmse:10.56453	valid-rmse:10.87233
# [1500]	train-rmse:10.49116	valid-rmse:10.80397
# [1600]	train-rmse:10.42014	valid-rmse:10.73453
# [1700]	train-rmse:10.35376	valid-rmse:10.67215
# [1800]	train-rmse:10.29184	valid-rmse:10.61319
# [1900]	train-rmse:10.23389	valid-rmse:10.55783
# [2000]	train-rmse:10.17482	valid-rmse:10.50147
# [2100]	train-rmse:10.12089	valid-rmse:10.45043
# [2200]	train-rmse:10.06996	valid-rmse:10.40162
# [2300]	train-rmse:10.02084	valid-rmse:10.35388
# [2400]	train-rmse:9.97328	valid-rmse:10.31080
# [2500]	train-rmse:9.92779	valid-rmse:10.26395
# [2600]	train-rmse:9.88481	valid-rmse:10.22375
# [2700]	train-rmse:9.84290	valid-rmse:10.18502
# [2800]	train-rmse:9.80394	valid-rmse:10.14804
# [2900]	train-rmse:9.76425	valid-rmse:10.10834
# [3000]	train-rmse:9.72807	valid-rmse:10.07474
# [3100]	train-rmse:9.69296	valid-rmse:10.04290
# [3200]	train-rmse:9.65829	valid-rmse:10.00892
# [3300]	train-rmse:9.62651	valid-rmse:9.97815
# [3400]	train-rmse:9.59582	valid-rmse:9.94857
# [3500]	train-rmse:9.56506	valid-rmse:9.91878
# [3600]	train-rmse:9.53566	valid-rmse:9.89251
# [3700]	train-rmse:9.50659	valid-rmse:9.86658
# [3800]	train-rmse:9.47748	valid-rmse:9.84070
# [3900]	train-rmse:9.45092	valid-rmse:9.81690
# [4000]	train-rmse:9.42436	valid-rmse:9.79535
# [4100]	train-rmse:9.39713	valid-rmse:9.77254
# [4200]	train-rmse:9.37184	valid-rmse:9.75077
# [4300]	train-rmse:9.34691	valid-rmse:9.73058
# [4400]	train-rmse:9.32121	valid-rmse:9.70867
# [4500]	train-rmse:9.29762	valid-rmse:9.68723
# [4600]	train-rmse:9.27440	valid-rmse:9.66704
# [4700]	train-rmse:9.25113	valid-rmse:9.64645
# [4800]	train-rmse:9.22781	valid-rmse:9.62480
# [4900]	train-rmse:9.20614	valid-rmse:9.60766
# [4999]	train-rmse:9.18674	valid-rmse:9.59151
# 3 0.001 0.6 0.2
# 0.6088361676090721
# [0]	train-rmse:12.18134	valid-rmse:12.43398
# [100]	train-rmse:12.00416	valid-rmse:12.26066
# [200]	train-rmse:11.83580	valid-rmse:12.09631
# [300]	train-rmse:11.67879	valid-rmse:11.94217
# [400]	train-rmse:11.53756	valid-rmse:11.80079
# [500]	train-rmse:11.39808	valid-rmse:11.66563
# [600]	train-rmse:11.27137	valid-rmse:11.54166
# [700]	train-rmse:11.14890	valid-rmse:11.42320
# [800]	train-rmse:11.03672	valid-rmse:11.31317
# [900]	train-rmse:10.93557	valid-rmse:11.21198
# [1000]	train-rmse:10.83313	valid-rmse:11.11625
# [1100]	train-rmse:10.73954	valid-rmse:11.02802
# [1200]	train-rmse:10.65155	valid-rmse:10.94288
# [1300]	train-rmse:10.56939	valid-rmse:10.86269
# [1400]	train-rmse:10.49007	valid-rmse:10.78804
# [1500]	train-rmse:10.41729	valid-rmse:10.71955
# [1600]	train-rmse:10.34829	valid-rmse:10.65163
# [1700]	train-rmse:10.28423	valid-rmse:10.59228
# [1800]	train-rmse:10.22197	valid-rmse:10.53363
# [1900]	train-rmse:10.16416	valid-rmse:10.47993
# [2000]	train-rmse:10.10648	valid-rmse:10.42542
# [2100]	train-rmse:10.05281	valid-rmse:10.37472
# [2200]	train-rmse:10.00260	valid-rmse:10.32682
# [2300]	train-rmse:9.95562	valid-rmse:10.28142
# [2400]	train-rmse:9.90861	valid-rmse:10.23837
# [2500]	train-rmse:9.86518	valid-rmse:10.19297
# [2600]	train-rmse:9.82290	valid-rmse:10.15346
# [2700]	train-rmse:9.78209	valid-rmse:10.11557
# [2800]	train-rmse:9.74381	valid-rmse:10.07887
# [2900]	train-rmse:9.70655	valid-rmse:10.04180
# [3000]	train-rmse:9.67120	valid-rmse:10.00835
# [3100]	train-rmse:9.63763	valid-rmse:9.97665
# [3200]	train-rmse:9.60308	valid-rmse:9.94136
# [3300]	train-rmse:9.57140	valid-rmse:9.91199
# [3400]	train-rmse:9.54130	valid-rmse:9.88463
# [3500]	train-rmse:9.51068	valid-rmse:9.85588
# [3600]	train-rmse:9.48105	valid-rmse:9.82789
# [3700]	train-rmse:9.45235	valid-rmse:9.80193
# [3800]	train-rmse:9.42439	valid-rmse:9.77570
# [3900]	train-rmse:9.39873	valid-rmse:9.75273
# [4000]	train-rmse:9.37248	valid-rmse:9.72980
# [4100]	train-rmse:9.34617	valid-rmse:9.70632
# [4200]	train-rmse:9.32134	valid-rmse:9.68357
# [4300]	train-rmse:9.29690	valid-rmse:9.66401
# [4400]	train-rmse:9.27225	valid-rmse:9.64131
# [4500]	train-rmse:9.24933	valid-rmse:9.62147
# [4600]	train-rmse:9.22668	valid-rmse:9.60209
# [4700]	train-rmse:9.20408	valid-rmse:9.58220
# [4800]	train-rmse:9.18057	valid-rmse:9.55997
# [4900]	train-rmse:9.15971	valid-rmse:9.54390
# [4999]	train-rmse:9.14041	valid-rmse:9.52913
# 3 0.001 0.6 0.25
# 0.6116862023818442
# [0]	train-rmse:12.18127	valid-rmse:12.43391
# [100]	train-rmse:11.99229	valid-rmse:12.24965
# [200]	train-rmse:11.81886	valid-rmse:12.07813
# [300]	train-rmse:11.65567	valid-rmse:11.91888
# [400]	train-rmse:11.50695	valid-rmse:11.77219
# [500]	train-rmse:11.36465	valid-rmse:11.63114
# [600]	train-rmse:11.23211	valid-rmse:11.49978
# [700]	train-rmse:11.10704	valid-rmse:11.37866
# [800]	train-rmse:10.99279	valid-rmse:11.26640
# [900]	train-rmse:10.88997	valid-rmse:11.16468
# [1000]	train-rmse:10.78632	valid-rmse:11.06614
# [1100]	train-rmse:10.69179	valid-rmse:10.97661
# [1200]	train-rmse:10.60486	valid-rmse:10.89503
# [1300]	train-rmse:10.52212	valid-rmse:10.81409
# [1400]	train-rmse:10.44208	valid-rmse:10.73766
# [1500]	train-rmse:10.36907	valid-rmse:10.66667
# [1600]	train-rmse:10.29980	valid-rmse:10.60078
# [1700]	train-rmse:10.23612	valid-rmse:10.54070
# [1800]	train-rmse:10.17413	valid-rmse:10.48117
# [1900]	train-rmse:10.11590	valid-rmse:10.42613
# [2000]	train-rmse:10.05914	valid-rmse:10.37269
# [2100]	train-rmse:10.00691	valid-rmse:10.32307
# [2200]	train-rmse:9.95789	valid-rmse:10.27575
# [2300]	train-rmse:9.91241	valid-rmse:10.23156
# [2400]	train-rmse:9.86781	valid-rmse:10.18977
# [2500]	train-rmse:9.82527	valid-rmse:10.14671
# [2600]	train-rmse:9.78441	valid-rmse:10.10778
# [2700]	train-rmse:9.74400	valid-rmse:10.06937
# [2800]	train-rmse:9.70622	valid-rmse:10.03129
# [2900]	train-rmse:9.66797	valid-rmse:9.99533
# [3000]	train-rmse:9.63328	valid-rmse:9.96345
# [3100]	train-rmse:9.59951	valid-rmse:9.93261
# [3200]	train-rmse:9.56632	valid-rmse:9.90147
# [3300]	train-rmse:9.53455	valid-rmse:9.87251
# [3400]	train-rmse:9.50544	valid-rmse:9.84697
# [3500]	train-rmse:9.47537	valid-rmse:9.81795
# [3600]	train-rmse:9.44497	valid-rmse:9.78966
# [3700]	train-rmse:9.41542	valid-rmse:9.76198
# [3800]	train-rmse:9.38763	valid-rmse:9.73630
# [3900]	train-rmse:9.36156	valid-rmse:9.71398
# [4000]	train-rmse:9.33558	valid-rmse:9.69095
# [4100]	train-rmse:9.31040	valid-rmse:9.66990
# [4200]	train-rmse:9.28602	valid-rmse:9.64819
# [4300]	train-rmse:9.26227	valid-rmse:9.62873
# [4400]	train-rmse:9.23816	valid-rmse:9.60559
# [4500]	train-rmse:9.21477	valid-rmse:9.58478
# [4600]	train-rmse:9.19158	valid-rmse:9.56565
# [4700]	train-rmse:9.17021	valid-rmse:9.54794
# [4800]	train-rmse:9.14822	valid-rmse:9.52782
# [4900]	train-rmse:9.12719	valid-rmse:9.51046
# [4999]	train-rmse:9.10788	valid-rmse:9.49690
# 3 0.001 0.6 0.3
# 0.6123406471406081
# [0]	train-rmse:12.18187	valid-rmse:12.43484
# [100]	train-rmse:12.01796	valid-rmse:12.27315
# [200]	train-rmse:11.85770	valid-rmse:12.11713
# [300]	train-rmse:11.71074	valid-rmse:11.97096
# [400]	train-rmse:11.57588	valid-rmse:11.84039
# [500]	train-rmse:11.44381	valid-rmse:11.71333
# [600]	train-rmse:11.32305	valid-rmse:11.59515
# [700]	train-rmse:11.20620	valid-rmse:11.48439
# [800]	train-rmse:11.09696	valid-rmse:11.37921
# [900]	train-rmse:10.99774	valid-rmse:11.28216
# [1000]	train-rmse:10.89939	valid-rmse:11.19125
# [1100]	train-rmse:10.80714	valid-rmse:11.10169
# [1200]	train-rmse:10.72326	valid-rmse:11.02116
# [1300]	train-rmse:10.64021	valid-rmse:10.94096
# [1400]	train-rmse:10.56046	valid-rmse:10.86453
# [1500]	train-rmse:10.48668	valid-rmse:10.79528
# [1600]	train-rmse:10.41462	valid-rmse:10.72718
# [1700]	train-rmse:10.34892	valid-rmse:10.66542
# [1800]	train-rmse:10.28619	valid-rmse:10.60664
# [1900]	train-rmse:10.22791	valid-rmse:10.55212
# [2000]	train-rmse:10.16919	valid-rmse:10.49590
# [2100]	train-rmse:10.11587	valid-rmse:10.44423
# [2200]	train-rmse:10.06473	valid-rmse:10.39602
# [2300]	train-rmse:10.01592	valid-rmse:10.34905
# [2400]	train-rmse:9.96888	valid-rmse:10.30577
# [2500]	train-rmse:9.92457	valid-rmse:10.26073
# [2600]	train-rmse:9.88141	valid-rmse:10.22095
# [2700]	train-rmse:9.84019	valid-rmse:10.18205
# [2800]	train-rmse:9.80213	valid-rmse:10.14748
# [2900]	train-rmse:9.76388	valid-rmse:10.10856
# [3000]	train-rmse:9.72682	valid-rmse:10.07392
# [3100]	train-rmse:9.69134	valid-rmse:10.04140
# [3200]	train-rmse:9.65865	valid-rmse:10.00861
# [3300]	train-rmse:9.62719	valid-rmse:9.97885
# [3400]	train-rmse:9.59573	valid-rmse:9.94859
# [3500]	train-rmse:9.56469	valid-rmse:9.91853
# [3600]	train-rmse:9.53531	valid-rmse:9.89210
# [3700]	train-rmse:9.50746	valid-rmse:9.86767
# [3800]	train-rmse:9.47943	valid-rmse:9.84248
# [3900]	train-rmse:9.45217	valid-rmse:9.81677
# [4000]	train-rmse:9.42561	valid-rmse:9.79529
# [4100]	train-rmse:9.39866	valid-rmse:9.77065
# [4200]	train-rmse:9.37404	valid-rmse:9.74899
# [4300]	train-rmse:9.34937	valid-rmse:9.72842
# [4400]	train-rmse:9.32436	valid-rmse:9.70612
# [4500]	train-rmse:9.30181	valid-rmse:9.68634
# [4600]	train-rmse:9.27908	valid-rmse:9.66568
# [4700]	train-rmse:9.25613	valid-rmse:9.64587
# [4800]	train-rmse:9.23437	valid-rmse:9.62726
# [4900]	train-rmse:9.21342	valid-rmse:9.60870
# [4999]	train-rmse:9.19362	valid-rmse:9.59278
# 3 0.001 0.7 0.2
# 0.6111319726675388
# [0]	train-rmse:12.18136	valid-rmse:12.43401
# [100]	train-rmse:12.00417	valid-rmse:12.26060
# [200]	train-rmse:11.83454	valid-rmse:12.09593
# [300]	train-rmse:11.67735	valid-rmse:11.94007
# [400]	train-rmse:11.53562	valid-rmse:11.79978
# [500]	train-rmse:11.39626	valid-rmse:11.66549
# [600]	train-rmse:11.26996	valid-rmse:11.54123
# [700]	train-rmse:11.14780	valid-rmse:11.42433
# [800]	train-rmse:11.03595	valid-rmse:11.31455
# [900]	train-rmse:10.93440	valid-rmse:11.21487
# [1000]	train-rmse:10.83313	valid-rmse:11.11940
# [1100]	train-rmse:10.74046	valid-rmse:11.03182
# [1200]	train-rmse:10.65302	valid-rmse:10.94861
# [1300]	train-rmse:10.57065	valid-rmse:10.86923
# [1400]	train-rmse:10.49033	valid-rmse:10.79216
# [1500]	train-rmse:10.41782	valid-rmse:10.72349
# [1600]	train-rmse:10.34890	valid-rmse:10.65704
# [1700]	train-rmse:10.28581	valid-rmse:10.59778
# [1800]	train-rmse:10.22406	valid-rmse:10.53975
# [1900]	train-rmse:10.16661	valid-rmse:10.48625
# [2000]	train-rmse:10.10915	valid-rmse:10.43073
# [2100]	train-rmse:10.05514	valid-rmse:10.37906
# [2200]	train-rmse:10.00391	valid-rmse:10.33089
# [2300]	train-rmse:9.95639	valid-rmse:10.28563
# [2400]	train-rmse:9.91053	valid-rmse:10.24339
# [2500]	train-rmse:9.86727	valid-rmse:10.20030
# [2600]	train-rmse:9.82553	valid-rmse:10.16198
# [2700]	train-rmse:9.78559	valid-rmse:10.12307
# [2800]	train-rmse:9.74780	valid-rmse:10.08711
# [2900]	train-rmse:9.71023	valid-rmse:10.04956
# [3000]	train-rmse:9.67498	valid-rmse:10.01417
# [3100]	train-rmse:9.64124	valid-rmse:9.98352
# [3200]	train-rmse:9.60972	valid-rmse:9.95218
# [3300]	train-rmse:9.57868	valid-rmse:9.92367
# [3400]	train-rmse:9.54786	valid-rmse:9.89556
# [3500]	train-rmse:9.51717	valid-rmse:9.86669
# [3600]	train-rmse:9.48817	valid-rmse:9.83948
# [3700]	train-rmse:9.45925	valid-rmse:9.81442
# [3800]	train-rmse:9.43175	valid-rmse:9.78839
# [3900]	train-rmse:9.40562	valid-rmse:9.76448
# [4000]	train-rmse:9.37951	valid-rmse:9.74372
# [4100]	train-rmse:9.35378	valid-rmse:9.72063
# [4200]	train-rmse:9.32954	valid-rmse:9.70057
# [4300]	train-rmse:9.30532	valid-rmse:9.68057
# [4400]	train-rmse:9.28110	valid-rmse:9.65807
# [4500]	train-rmse:9.25925	valid-rmse:9.63905
# [4600]	train-rmse:9.23662	valid-rmse:9.61874
# [4700]	train-rmse:9.21409	valid-rmse:9.60026
# [4800]	train-rmse:9.19247	valid-rmse:9.58238
# [4900]	train-rmse:9.17224	valid-rmse:9.56591
# [4999]	train-rmse:9.15225	valid-rmse:9.55092
# 3 0.001 0.7 0.25
# 0.6109545568570096
# [0]	train-rmse:12.18131	valid-rmse:12.43394
# [100]	train-rmse:11.99237	valid-rmse:12.24938
# [200]	train-rmse:11.81656	valid-rmse:12.07601
# [300]	train-rmse:11.65242	valid-rmse:11.91479
# [400]	train-rmse:11.50304	valid-rmse:11.76661
# [500]	train-rmse:11.36017	valid-rmse:11.62672
# [600]	train-rmse:11.22772	valid-rmse:11.49594
# [700]	train-rmse:11.10213	valid-rmse:11.37396
# [800]	train-rmse:10.98676	valid-rmse:11.26135
# [900]	train-rmse:10.88527	valid-rmse:11.16128
# [1000]	train-rmse:10.78191	valid-rmse:11.06292
# [1100]	train-rmse:10.68850	valid-rmse:10.97345
# [1200]	train-rmse:10.60019	valid-rmse:10.88927
# [1300]	train-rmse:10.51607	valid-rmse:10.80713
# [1400]	train-rmse:10.43528	valid-rmse:10.73159
# [1500]	train-rmse:10.36214	valid-rmse:10.65945
# [1600]	train-rmse:10.29285	valid-rmse:10.59363
# [1700]	train-rmse:10.23071	valid-rmse:10.53418
# [1800]	train-rmse:10.16862	valid-rmse:10.47562
# [1900]	train-rmse:10.11115	valid-rmse:10.42076
# [2000]	train-rmse:10.05493	valid-rmse:10.36794
# [2100]	train-rmse:10.00194	valid-rmse:10.31710
# [2200]	train-rmse:9.95178	valid-rmse:10.26959
# [2300]	train-rmse:9.90476	valid-rmse:10.22478
# [2400]	train-rmse:9.86045	valid-rmse:10.18156
# [2500]	train-rmse:9.81704	valid-rmse:10.13940
# [2600]	train-rmse:9.77788	valid-rmse:10.10182
# [2700]	train-rmse:9.73825	valid-rmse:10.06426
# [2800]	train-rmse:9.70190	valid-rmse:10.02951
# [2900]	train-rmse:9.66439	valid-rmse:9.99269
# [3000]	train-rmse:9.62947	valid-rmse:9.96036
# [3100]	train-rmse:9.59724	valid-rmse:9.92999
# [3200]	train-rmse:9.56557	valid-rmse:9.90015
# [3300]	train-rmse:9.53477	valid-rmse:9.87163
# [3400]	train-rmse:9.50404	valid-rmse:9.84229
# [3500]	train-rmse:9.47535	valid-rmse:9.81456
# [3600]	train-rmse:9.44533	valid-rmse:9.78700
# [3700]	train-rmse:9.41723	valid-rmse:9.76211
# [3800]	train-rmse:9.39009	valid-rmse:9.73754
# [3900]	train-rmse:9.36355	valid-rmse:9.71373
# [4000]	train-rmse:9.33799	valid-rmse:9.69324
# [4100]	train-rmse:9.31363	valid-rmse:9.67364
# [4200]	train-rmse:9.28937	valid-rmse:9.65383
# [4300]	train-rmse:9.26511	valid-rmse:9.63256
# [4400]	train-rmse:9.24183	valid-rmse:9.61176
# [4500]	train-rmse:9.21930	valid-rmse:9.59295
# [4600]	train-rmse:9.19718	valid-rmse:9.57338
# [4700]	train-rmse:9.17567	valid-rmse:9.55465
# [4800]	train-rmse:9.15436	valid-rmse:9.53603
# [4900]	train-rmse:9.13354	valid-rmse:9.51985
# [4999]	train-rmse:9.11368	valid-rmse:9.50594
# 3 0.001 0.7 0.3
# 0.6122411340338687
# [0]	train-rmse:12.17316	valid-rmse:12.42791
# [100]	train-rmse:11.45937	valid-rmse:11.73667
# [200]	train-rmse:10.91100	valid-rmse:11.20718
# [300]	train-rmse:10.50069	valid-rmse:10.80533
# [400]	train-rmse:10.19119	valid-rmse:10.51180
# [500]	train-rmse:9.94367	valid-rmse:10.28569
# [600]	train-rmse:9.73855	valid-rmse:10.09382
# [700]	train-rmse:9.57722	valid-rmse:9.94449
# [800]	train-rmse:9.43785	valid-rmse:9.82005
# [900]	train-rmse:9.30795	valid-rmse:9.70375
# [1000]	train-rmse:9.19163	valid-rmse:9.60697
# [1100]	train-rmse:9.09094	valid-rmse:9.52098
# [1200]	train-rmse:9.00499	valid-rmse:9.44786
# [1300]	train-rmse:8.92351	valid-rmse:9.38542
# [1400]	train-rmse:8.84165	valid-rmse:9.31358
# [1500]	train-rmse:8.77268	valid-rmse:9.26314
# [1600]	train-rmse:8.70678	valid-rmse:9.20893
# [1700]	train-rmse:8.64823	valid-rmse:9.17137
# [1800]	train-rmse:8.58729	valid-rmse:9.12293
# [1900]	train-rmse:8.53549	valid-rmse:9.09366
# [2000]	train-rmse:8.48269	valid-rmse:9.05596
# [2100]	train-rmse:8.43484	valid-rmse:9.02700
# [2200]	train-rmse:8.39285	valid-rmse:8.99682
# [2300]	train-rmse:8.35131	valid-rmse:8.96816
# [2400]	train-rmse:8.31215	valid-rmse:8.93884
# [2500]	train-rmse:8.27313	valid-rmse:8.91661
# [2600]	train-rmse:8.23509	valid-rmse:8.89589
# [2700]	train-rmse:8.19953	valid-rmse:8.88086
# [2800]	train-rmse:8.16238	valid-rmse:8.86628
# [2900]	train-rmse:8.12926	valid-rmse:8.84871
# [3000]	train-rmse:8.09793	valid-rmse:8.83971
# [3100]	train-rmse:8.06954	valid-rmse:8.82966
# [3200]	train-rmse:8.04308	valid-rmse:8.81783
# [3300]	train-rmse:8.01632	valid-rmse:8.80772
# [3400]	train-rmse:7.99114	valid-rmse:8.79566
# [3500]	train-rmse:7.96623	valid-rmse:8.78958
# [3600]	train-rmse:7.94350	valid-rmse:8.78707
# [3700]	train-rmse:7.92039	valid-rmse:8.78031
# [3800]	train-rmse:7.89841	valid-rmse:8.77350
# [3900]	train-rmse:7.87653	valid-rmse:8.77148
# [4000]	train-rmse:7.85457	valid-rmse:8.76457
# [4100]	train-rmse:7.83434	valid-rmse:8.76122
# [4200]	train-rmse:7.81258	valid-rmse:8.75598
# [4300]	train-rmse:7.79417	valid-rmse:8.75286
# [4400]	train-rmse:7.77411	valid-rmse:8.74915
# [4500]	train-rmse:7.75415	valid-rmse:8.74710
# [4600]	train-rmse:7.73736	valid-rmse:8.74677
# [4700]	train-rmse:7.72063	valid-rmse:8.74114
# [4800]	train-rmse:7.70151	valid-rmse:8.73331
# [4900]	train-rmse:7.68569	valid-rmse:8.72854
# [4999]	train-rmse:7.66913	valid-rmse:8.72818
# 3 0.005 0.5 0.2
# 0.6516097225188097
# [0]	train-rmse:12.17088	valid-rmse:12.42272
# [100]	train-rmse:11.40046	valid-rmse:11.67934
# [200]	train-rmse:10.84029	valid-rmse:11.13939
# [300]	train-rmse:10.42706	valid-rmse:10.72889
# [400]	train-rmse:10.12119	valid-rmse:10.42951
# [500]	train-rmse:9.87700	valid-rmse:10.19736
# [600]	train-rmse:9.67955	valid-rmse:10.01240
# [700]	train-rmse:9.52204	valid-rmse:9.86073
# [800]	train-rmse:9.38624	valid-rmse:9.73934
# [900]	train-rmse:9.26309	valid-rmse:9.62258
# [1000]	train-rmse:9.14972	valid-rmse:9.53459
# [1100]	train-rmse:9.04825	valid-rmse:9.44548
# [1200]	train-rmse:8.95780	valid-rmse:9.36880
# [1300]	train-rmse:8.87749	valid-rmse:9.30540
# [1400]	train-rmse:8.79709	valid-rmse:9.23803
# [1500]	train-rmse:8.72667	valid-rmse:9.18834
# [1600]	train-rmse:8.66259	valid-rmse:9.13397
# [1700]	train-rmse:8.60670	valid-rmse:9.10015
# [1800]	train-rmse:8.54891	valid-rmse:9.05230
# [1900]	train-rmse:8.49723	valid-rmse:9.02379
# [2000]	train-rmse:8.44643	valid-rmse:8.99531
# [2100]	train-rmse:8.39756	valid-rmse:8.96717
# [2200]	train-rmse:8.35860	valid-rmse:8.94145
# [2300]	train-rmse:8.31671	valid-rmse:8.91836
# [2400]	train-rmse:8.27984	valid-rmse:8.89569
# [2500]	train-rmse:8.24216	valid-rmse:8.87413
# [2600]	train-rmse:8.20617	valid-rmse:8.85661
# [2700]	train-rmse:8.16960	valid-rmse:8.84247
# [2800]	train-rmse:8.13467	valid-rmse:8.83026
# [2900]	train-rmse:8.10156	valid-rmse:8.82075
# [3000]	train-rmse:8.07064	valid-rmse:8.80950
# [3100]	train-rmse:8.04120	valid-rmse:8.79363
# [3200]	train-rmse:8.01502	valid-rmse:8.78314
# [3300]	train-rmse:7.98687	valid-rmse:8.77281
# [3400]	train-rmse:7.96185	valid-rmse:8.76180
# [3500]	train-rmse:7.93798	valid-rmse:8.75556
# [3600]	train-rmse:7.91383	valid-rmse:8.75461
# [3671]	train-rmse:7.89694	valid-rmse:8.75343
# 3 0.005 0.5 0.25
# 0.6484933448364583
# [0]	train-rmse:12.17067	valid-rmse:12.42250
# [100]	train-rmse:11.36336	valid-rmse:11.65207
# [200]	train-rmse:10.79539	valid-rmse:11.09415
# [300]	train-rmse:10.38540	valid-rmse:10.68749
# [400]	train-rmse:10.07424	valid-rmse:10.37949
# [500]	train-rmse:9.83999	valid-rmse:10.16375
# [600]	train-rmse:9.64008	valid-rmse:9.97712
# [700]	train-rmse:9.48371	valid-rmse:9.82725
# [800]	train-rmse:9.34864	valid-rmse:9.70973
# [900]	train-rmse:9.22533	valid-rmse:9.60207
# [1000]	train-rmse:9.11040	valid-rmse:9.51170
# [1100]	train-rmse:9.00949	valid-rmse:9.42860
# [1200]	train-rmse:8.92008	valid-rmse:9.35081
# [1300]	train-rmse:8.84023	valid-rmse:9.28873
# [1400]	train-rmse:8.76065	valid-rmse:9.22287
# [1500]	train-rmse:8.68869	valid-rmse:9.16981
# [1600]	train-rmse:8.62509	valid-rmse:9.11828
# [1700]	train-rmse:8.56829	valid-rmse:9.08729
# [1800]	train-rmse:8.51299	valid-rmse:9.04152
# [1900]	train-rmse:8.46120	valid-rmse:9.01627
# [2000]	train-rmse:8.41163	valid-rmse:8.98995
# [2100]	train-rmse:8.36341	valid-rmse:8.95842
# [2200]	train-rmse:8.32455	valid-rmse:8.93512
# [2300]	train-rmse:8.28155	valid-rmse:8.90798
# [2400]	train-rmse:8.24387	valid-rmse:8.89035
# [2500]	train-rmse:8.20593	valid-rmse:8.87059
# [2600]	train-rmse:8.16993	valid-rmse:8.85173
# [2700]	train-rmse:8.13266	valid-rmse:8.84076
# [2800]	train-rmse:8.09898	valid-rmse:8.82966
# [2900]	train-rmse:8.06707	valid-rmse:8.82160
# [3000]	train-rmse:8.03848	valid-rmse:8.81599
# [3100]	train-rmse:8.00887	valid-rmse:8.80342
# [3200]	train-rmse:7.98210	valid-rmse:8.79597
# [3300]	train-rmse:7.95479	valid-rmse:8.78492
# [3400]	train-rmse:7.92981	valid-rmse:8.77657
# [3500]	train-rmse:7.90694	valid-rmse:8.77262
# [3600]	train-rmse:7.88336	valid-rmse:8.76902
# [3700]	train-rmse:7.85938	valid-rmse:8.76724
# [3800]	train-rmse:7.83717	valid-rmse:8.76047
# [3900]	train-rmse:7.81578	valid-rmse:8.75574
# [4000]	train-rmse:7.79355	valid-rmse:8.74628
# [4100]	train-rmse:7.77346	valid-rmse:8.74560
# [4151]	train-rmse:7.76272	valid-rmse:8.74398
# 3 0.005 0.5 0.3
# 0.6479784100674157
# [0]	train-rmse:12.17325	valid-rmse:12.42803
# [100]	train-rmse:11.45228	valid-rmse:11.72588
# [200]	train-rmse:10.90317	valid-rmse:11.19226
# [300]	train-rmse:10.48735	valid-rmse:10.78647
# [400]	train-rmse:10.17720	valid-rmse:10.49280
# [500]	train-rmse:9.92503	valid-rmse:10.26660
# [600]	train-rmse:9.72467	valid-rmse:10.07625
# [700]	train-rmse:9.55777	valid-rmse:9.92481
# [800]	train-rmse:9.42289	valid-rmse:9.80592
# [900]	train-rmse:9.29729	valid-rmse:9.68882
# [1000]	train-rmse:9.18522	valid-rmse:9.59943
# [1100]	train-rmse:9.09244	valid-rmse:9.51920
# [1200]	train-rmse:9.00486	valid-rmse:9.44116
# [1300]	train-rmse:8.92079	valid-rmse:9.38132
# [1400]	train-rmse:8.84093	valid-rmse:9.30986
# [1500]	train-rmse:8.77191	valid-rmse:9.25778
# [1600]	train-rmse:8.70545	valid-rmse:9.20438
# [1700]	train-rmse:8.64527	valid-rmse:9.16275
# [1800]	train-rmse:8.58968	valid-rmse:9.12329
# [1900]	train-rmse:8.53496	valid-rmse:9.09358
# [2000]	train-rmse:8.48170	valid-rmse:9.05555
# [2100]	train-rmse:8.43768	valid-rmse:9.02368
# [2200]	train-rmse:8.39720	valid-rmse:8.99691
# [2300]	train-rmse:8.35707	valid-rmse:8.97662
# [2400]	train-rmse:8.31808	valid-rmse:8.95343
# [2500]	train-rmse:8.27803	valid-rmse:8.92898
# [2600]	train-rmse:8.24228	valid-rmse:8.90867
# [2700]	train-rmse:8.20348	valid-rmse:8.88637
# [2800]	train-rmse:8.16713	valid-rmse:8.86516
# [2900]	train-rmse:8.13395	valid-rmse:8.84582
# [3000]	train-rmse:8.10451	valid-rmse:8.82918
# [3100]	train-rmse:8.07484	valid-rmse:8.81363
# [3200]	train-rmse:8.04734	valid-rmse:8.79793
# [3300]	train-rmse:8.02042	valid-rmse:8.78621
# [3400]	train-rmse:7.99173	valid-rmse:8.77857
# [3500]	train-rmse:7.96739	valid-rmse:8.77341
# [3600]	train-rmse:7.94516	valid-rmse:8.76625
# [3700]	train-rmse:7.92103	valid-rmse:8.76467
# [3768]	train-rmse:7.90536	valid-rmse:8.76224
# 3 0.005 0.6 0.2
# 0.646866584467815
# [0]	train-rmse:12.17070	valid-rmse:12.42261
# [100]	train-rmse:11.39941	valid-rmse:11.67443
# [200]	train-rmse:10.83801	valid-rmse:11.12690
# [300]	train-rmse:10.41965	valid-rmse:10.71689
# [400]	train-rmse:10.11089	valid-rmse:10.41266
# [500]	train-rmse:9.86689	valid-rmse:10.18384
# [600]	train-rmse:9.66735	valid-rmse:9.99705
# [700]	train-rmse:9.50674	valid-rmse:9.84142
# [800]	train-rmse:9.36632	valid-rmse:9.72459
# [900]	train-rmse:9.24303	valid-rmse:9.61579
# [1000]	train-rmse:9.13647	valid-rmse:9.52875
# [1100]	train-rmse:9.04126	valid-rmse:9.44833
# [1200]	train-rmse:8.95301	valid-rmse:9.37518
# [1300]	train-rmse:8.86973	valid-rmse:9.31902
# [1400]	train-rmse:8.78930	valid-rmse:9.25125
# [1500]	train-rmse:8.72261	valid-rmse:9.20275
# [1600]	train-rmse:8.65977	valid-rmse:9.15031
# [1700]	train-rmse:8.60377	valid-rmse:9.11337
# [1800]	train-rmse:8.54804	valid-rmse:9.07536
# [1900]	train-rmse:8.49505	valid-rmse:9.04255
# [2000]	train-rmse:8.44492	valid-rmse:9.01360
# [2100]	train-rmse:8.40023	valid-rmse:8.98345
# [2200]	train-rmse:8.35997	valid-rmse:8.95695
# [2300]	train-rmse:8.32021	valid-rmse:8.93694
# [2400]	train-rmse:8.28064	valid-rmse:8.91521
# [2500]	train-rmse:8.23916	valid-rmse:8.88677
# [2600]	train-rmse:8.20334	valid-rmse:8.86789
# [2700]	train-rmse:8.16627	valid-rmse:8.85030
# [2800]	train-rmse:8.13276	valid-rmse:8.83493
# [2900]	train-rmse:8.09998	valid-rmse:8.82048
# [3000]	train-rmse:8.07083	valid-rmse:8.80686
# [3100]	train-rmse:8.04074	valid-rmse:8.78972
# [3200]	train-rmse:8.01226	valid-rmse:8.77759
# [3300]	train-rmse:7.98443	valid-rmse:8.77160
# [3400]	train-rmse:7.95623	valid-rmse:8.75883
# [3500]	train-rmse:7.93167	valid-rmse:8.75309
# [3600]	train-rmse:7.90963	valid-rmse:8.74686
# [3700]	train-rmse:7.88425	valid-rmse:8.74590
# [3800]	train-rmse:7.86106	valid-rmse:8.74385
# [3900]	train-rmse:7.83830	valid-rmse:8.73661
# [4000]	train-rmse:7.81519	valid-rmse:8.73202
# [4100]	train-rmse:7.79366	valid-rmse:8.72589
# [4200]	train-rmse:7.77176	valid-rmse:8.72477
# [4300]	train-rmse:7.75231	valid-rmse:8.72369
# [4400]	train-rmse:7.73201	valid-rmse:8.72156
# [4500]	train-rmse:7.71229	valid-rmse:8.71917
# [4600]	train-rmse:7.69426	valid-rmse:8.71637
# [4700]	train-rmse:7.67602	valid-rmse:8.71413
# [4800]	train-rmse:7.65680	valid-rmse:8.71065
# [4900]	train-rmse:7.63992	valid-rmse:8.70888
# [4999]	train-rmse:7.62284	valid-rmse:8.71033
# 3 0.005 0.6 0.25
# 0.6529860961647852
# [0]	train-rmse:12.17037	valid-rmse:12.42227
# [100]	train-rmse:11.35632	valid-rmse:11.62399
# [200]	train-rmse:10.78462	valid-rmse:11.07666
# [300]	train-rmse:10.36601	valid-rmse:10.66982
# [400]	train-rmse:10.05717	valid-rmse:10.37286
# [500]	train-rmse:9.82786	valid-rmse:10.15676
# [600]	train-rmse:9.63134	valid-rmse:9.97395
# [700]	train-rmse:9.47239	valid-rmse:9.82588
# [800]	train-rmse:9.33625	valid-rmse:9.71511
# [900]	train-rmse:9.21576	valid-rmse:9.61713
# [1000]	train-rmse:9.10597	valid-rmse:9.52480
# [1100]	train-rmse:9.00813	valid-rmse:9.44558
# [1200]	train-rmse:8.91965	valid-rmse:9.37399
# [1300]	train-rmse:8.83960	valid-rmse:9.31681
# [1400]	train-rmse:8.76244	valid-rmse:9.24895
# [1500]	train-rmse:8.69819	valid-rmse:9.20399
# [1600]	train-rmse:8.63473	valid-rmse:9.15923
# [1700]	train-rmse:8.57888	valid-rmse:9.12374
# [1800]	train-rmse:8.52215	valid-rmse:9.07985
# [1900]	train-rmse:8.46899	valid-rmse:9.04991
# [2000]	train-rmse:8.41936	valid-rmse:9.02145
# [2100]	train-rmse:8.37460	valid-rmse:8.99196
# [2200]	train-rmse:8.33630	valid-rmse:8.96911
# [2300]	train-rmse:8.29519	valid-rmse:8.94874
# [2400]	train-rmse:8.25603	valid-rmse:8.92710
# [2500]	train-rmse:8.21507	valid-rmse:8.90382
# [2600]	train-rmse:8.17897	valid-rmse:8.88370
# [2700]	train-rmse:8.14128	valid-rmse:8.86390
# [2800]	train-rmse:8.10874	valid-rmse:8.84688
# [2900]	train-rmse:8.07570	valid-rmse:8.83433
# [3000]	train-rmse:8.04790	valid-rmse:8.82464
# [3100]	train-rmse:8.01850	valid-rmse:8.81042
# [3200]	train-rmse:7.99001	valid-rmse:8.79629
# [3300]	train-rmse:7.96474	valid-rmse:8.79379
# [3400]	train-rmse:7.93728	valid-rmse:8.78306
# [3500]	train-rmse:7.91258	valid-rmse:8.77673
# [3600]	train-rmse:7.88885	valid-rmse:8.76971
# [3700]	train-rmse:7.86443	valid-rmse:8.76973
# [3800]	train-rmse:7.84141	valid-rmse:8.76900
# [3900]	train-rmse:7.81934	valid-rmse:8.76143
# [4000]	train-rmse:7.79565	valid-rmse:8.75647
# [4100]	train-rmse:7.77428	valid-rmse:8.75083
# [4200]	train-rmse:7.75317	valid-rmse:8.74758
# [4300]	train-rmse:7.73325	valid-rmse:8.74617
# [4400]	train-rmse:7.71291	valid-rmse:8.74639
# [4500]	train-rmse:7.69298	valid-rmse:8.74199
# [4600]	train-rmse:7.67567	valid-rmse:8.73616
# [4700]	train-rmse:7.65697	valid-rmse:8.73342
# [4800]	train-rmse:7.63766	valid-rmse:8.72931
# [4900]	train-rmse:7.62179	valid-rmse:8.72737
# [4999]	train-rmse:7.60456	valid-rmse:8.73030
# 3 0.005 0.6 0.3
# 0.6528095641379686
# [0]	train-rmse:12.17334	valid-rmse:12.42690
# [100]	train-rmse:11.44894	valid-rmse:11.71973
# [200]	train-rmse:10.89602	valid-rmse:11.18884
# [300]	train-rmse:10.48528	valid-rmse:10.77582
# [400]	train-rmse:10.16778	valid-rmse:10.47873
# [500]	train-rmse:9.92468	valid-rmse:10.25929
# [600]	train-rmse:9.72459	valid-rmse:10.07508
# [700]	train-rmse:9.56084	valid-rmse:9.92248
# [800]	train-rmse:9.42098	valid-rmse:9.79626
# [900]	train-rmse:9.29323	valid-rmse:9.68093
# [1000]	train-rmse:9.18322	valid-rmse:9.59759
# [1100]	train-rmse:9.09147	valid-rmse:9.52269
# [1200]	train-rmse:9.00489	valid-rmse:9.44690
# [1300]	train-rmse:8.92313	valid-rmse:9.38449
# [1400]	train-rmse:8.84445	valid-rmse:9.31634
# [1500]	train-rmse:8.77705	valid-rmse:9.26852
# [1600]	train-rmse:8.70763	valid-rmse:9.21653
# [1700]	train-rmse:8.65032	valid-rmse:9.18035
# [1800]	train-rmse:8.59253	valid-rmse:9.13508
# [1900]	train-rmse:8.53950	valid-rmse:9.10711
# [2000]	train-rmse:8.48636	valid-rmse:9.07336
# [2100]	train-rmse:8.44177	valid-rmse:9.04529
# [2200]	train-rmse:8.40010	valid-rmse:9.02373
# [2300]	train-rmse:8.35966	valid-rmse:9.00272
# [2400]	train-rmse:8.31960	valid-rmse:8.97805
# [2500]	train-rmse:8.27879	valid-rmse:8.95419
# [2600]	train-rmse:8.24208	valid-rmse:8.93419
# [2700]	train-rmse:8.20663	valid-rmse:8.91579
# [2800]	train-rmse:8.17006	valid-rmse:8.89535
# [2900]	train-rmse:8.13647	valid-rmse:8.87853
# [3000]	train-rmse:8.10534	valid-rmse:8.86316
# [3100]	train-rmse:8.07739	valid-rmse:8.85098
# [3200]	train-rmse:8.04783	valid-rmse:8.83747
# [3300]	train-rmse:8.02189	valid-rmse:8.82649
# [3400]	train-rmse:7.99429	valid-rmse:8.81739
# [3500]	train-rmse:7.96921	valid-rmse:8.80830
# [3600]	train-rmse:7.94489	valid-rmse:8.80262
# [3700]	train-rmse:7.92074	valid-rmse:8.79657
# [3800]	train-rmse:7.89521	valid-rmse:8.78589
# [3900]	train-rmse:7.87232	valid-rmse:8.77879
# [4000]	train-rmse:7.85015	valid-rmse:8.77462
# [4100]	train-rmse:7.82677	valid-rmse:8.77137
# [4200]	train-rmse:7.80525	valid-rmse:8.76801
# [4300]	train-rmse:7.78464	valid-rmse:8.76414
# [4400]	train-rmse:7.76398	valid-rmse:8.76064
# [4500]	train-rmse:7.74477	valid-rmse:8.75459
# [4600]	train-rmse:7.72481	valid-rmse:8.74766
# [4700]	train-rmse:7.70520	valid-rmse:8.74880
# [4800]	train-rmse:7.68693	valid-rmse:8.74221
# [4900]	train-rmse:7.66860	valid-rmse:8.73884
# [4999]	train-rmse:7.65095	valid-rmse:8.73687
# 3 0.005 0.7 0.2
# 0.6507644035942823
# [0]	train-rmse:12.17083	valid-rmse:12.42280
# [100]	train-rmse:11.39553	valid-rmse:11.67099
# [200]	train-rmse:10.82906	valid-rmse:11.12359
# [300]	train-rmse:10.41944	valid-rmse:10.71502
# [400]	train-rmse:10.10847	valid-rmse:10.41414
# [500]	train-rmse:9.85799	valid-rmse:10.17656
# [600]	train-rmse:9.66783	valid-rmse:9.99887
# [700]	train-rmse:9.50884	valid-rmse:9.85494
# [800]	train-rmse:9.37763	valid-rmse:9.74036
# [900]	train-rmse:9.24939	valid-rmse:9.62421
# [1000]	train-rmse:9.14467	valid-rmse:9.53714
# [1100]	train-rmse:9.04985	valid-rmse:9.45976
# [1200]	train-rmse:8.96286	valid-rmse:9.38954
# [1300]	train-rmse:8.88154	valid-rmse:9.32697
# [1400]	train-rmse:8.80424	valid-rmse:9.25784
# [1500]	train-rmse:8.73509	valid-rmse:9.21515
# [1600]	train-rmse:8.66645	valid-rmse:9.16877
# [1700]	train-rmse:8.60918	valid-rmse:9.13513
# [1800]	train-rmse:8.55098	valid-rmse:9.09184
# [1900]	train-rmse:8.50085	valid-rmse:9.06775
# [2000]	train-rmse:8.45109	valid-rmse:9.03810
# [2100]	train-rmse:8.40598	valid-rmse:9.01568
# [2200]	train-rmse:8.36549	valid-rmse:8.99352
# [2300]	train-rmse:8.32549	valid-rmse:8.97480
# [2400]	train-rmse:8.28690	valid-rmse:8.95439
# [2500]	train-rmse:8.24901	valid-rmse:8.93157
# [2600]	train-rmse:8.21292	valid-rmse:8.90984
# [2700]	train-rmse:8.17775	valid-rmse:8.89149
# [2800]	train-rmse:8.14393	valid-rmse:8.87672
# [2900]	train-rmse:8.11045	valid-rmse:8.86351
# [3000]	train-rmse:8.07922	valid-rmse:8.85229
# [3100]	train-rmse:8.04986	valid-rmse:8.83907
# [3200]	train-rmse:8.01997	valid-rmse:8.82762
# [3300]	train-rmse:7.99516	valid-rmse:8.82347
# [3400]	train-rmse:7.96810	valid-rmse:8.80973
# [3500]	train-rmse:7.94152	valid-rmse:8.80036
# [3600]	train-rmse:7.91861	valid-rmse:8.79817
# [3662]	train-rmse:7.90323	valid-rmse:8.79515
# 3 0.005 0.7 0.25
# 0.6445835849561198
# [0]	train-rmse:12.17054	valid-rmse:12.42242
# [100]	train-rmse:11.35049	valid-rmse:11.62400
# [200]	train-rmse:10.78180	valid-rmse:11.07172
# [300]	train-rmse:10.37713	valid-rmse:10.67229
# [400]	train-rmse:10.06602	valid-rmse:10.37742
# [500]	train-rmse:9.82171	valid-rmse:10.14300
# [600]	train-rmse:9.63164	valid-rmse:9.97529
# [700]	train-rmse:9.47613	valid-rmse:9.83514
# [800]	train-rmse:9.34182	valid-rmse:9.71821
# [900]	train-rmse:9.21840	valid-rmse:9.61042
# [1000]	train-rmse:9.11521	valid-rmse:9.53032
# [1100]	train-rmse:9.02239	valid-rmse:9.46168
# [1200]	train-rmse:8.93431	valid-rmse:9.39034
# [1300]	train-rmse:8.85643	valid-rmse:9.33380
# [1400]	train-rmse:8.77865	valid-rmse:9.26577
# [1500]	train-rmse:8.71087	valid-rmse:9.22553
# [1600]	train-rmse:8.64226	valid-rmse:9.17734
# [1700]	train-rmse:8.58554	valid-rmse:9.14342
# [1800]	train-rmse:8.52862	valid-rmse:9.09637
# [1900]	train-rmse:8.47757	valid-rmse:9.07491
# [2000]	train-rmse:8.42871	valid-rmse:9.04754
# [2100]	train-rmse:8.38134	valid-rmse:9.01922
# [2200]	train-rmse:8.34088	valid-rmse:8.99983
# [2300]	train-rmse:8.29993	valid-rmse:8.98198
# [2400]	train-rmse:8.25960	valid-rmse:8.95965
# [2500]	train-rmse:8.22244	valid-rmse:8.93937
# [2600]	train-rmse:8.18707	valid-rmse:8.92244
# [2700]	train-rmse:8.15242	valid-rmse:8.90894
# [2800]	train-rmse:8.12053	valid-rmse:8.89423
# [2900]	train-rmse:8.08777	valid-rmse:8.87771
# [3000]	train-rmse:8.05714	valid-rmse:8.86495
# [3100]	train-rmse:8.02865	valid-rmse:8.85203
# [3200]	train-rmse:7.99874	valid-rmse:8.84041
# [3300]	train-rmse:7.97238	valid-rmse:8.83500
# [3400]	train-rmse:7.94614	valid-rmse:8.82321
# [3500]	train-rmse:7.91868	valid-rmse:8.81690
# [3600]	train-rmse:7.89674	valid-rmse:8.81560
# [3700]	train-rmse:7.87197	valid-rmse:8.80901
# [3800]	train-rmse:7.84526	valid-rmse:8.79402
# [3900]	train-rmse:7.82174	valid-rmse:8.79038
# [4000]	train-rmse:7.79991	valid-rmse:8.79053
# [4100]	train-rmse:7.77810	valid-rmse:8.78604
# [4200]	train-rmse:7.75669	valid-rmse:8.77993
# [4300]	train-rmse:7.73742	valid-rmse:8.77337
# [4400]	train-rmse:7.71749	valid-rmse:8.77168
# [4500]	train-rmse:7.69842	valid-rmse:8.76912
# [4600]	train-rmse:7.67842	valid-rmse:8.76296
# [4700]	train-rmse:7.65956	valid-rmse:8.76675
# [4721]	train-rmse:7.65586	valid-rmse:8.76581
# 3 0.005 0.7 0.3
# 0.6505846498091932
# [0]	train-rmse:12.16236	valid-rmse:12.41902
# [100]	train-rmse:10.92372	valid-rmse:11.22678
# [200]	train-rmse:10.20685	valid-rmse:10.52737
# [300]	train-rmse:9.74841	valid-rmse:10.07610
# [400]	train-rmse:9.43896	valid-rmse:9.80070
# [500]	train-rmse:9.20678	valid-rmse:9.60822
# [600]	train-rmse:9.00446	valid-rmse:9.44639
# [700]	train-rmse:8.84483	valid-rmse:9.30855
# [800]	train-rmse:8.71159	valid-rmse:9.21297
# [900]	train-rmse:8.59027	valid-rmse:9.11500
# [1000]	train-rmse:8.48024	valid-rmse:9.05322
# [1100]	train-rmse:8.38796	valid-rmse:9.00200
# [1200]	train-rmse:8.31270	valid-rmse:8.95721
# [1300]	train-rmse:8.24146	valid-rmse:8.92558
# [1400]	train-rmse:8.17036	valid-rmse:8.88224
# [1500]	train-rmse:8.10781	valid-rmse:8.85187
# [1600]	train-rmse:8.05071	valid-rmse:8.83758
# [1700]	train-rmse:8.00085	valid-rmse:8.83132
# [1800]	train-rmse:7.94795	valid-rmse:8.80553
# [1900]	train-rmse:7.90100	valid-rmse:8.80384
# [1918]	train-rmse:7.88994	valid-rmse:8.80016
# 3 0.01 0.5 0.2
# 0.6451125425804145
# [0]	train-rmse:12.15781	valid-rmse:12.40866
# [100]	train-rmse:10.84071	valid-rmse:11.13573
# [200]	train-rmse:10.13692	valid-rmse:10.45080
# [300]	train-rmse:9.69824	valid-rmse:10.02435
# [400]	train-rmse:9.39798	valid-rmse:9.75397
# [500]	train-rmse:9.16558	valid-rmse:9.54823
# [600]	train-rmse:8.96945	valid-rmse:9.39952
# [700]	train-rmse:8.81149	valid-rmse:9.27120
# [800]	train-rmse:8.67661	valid-rmse:9.18244
# [900]	train-rmse:8.55779	valid-rmse:9.08766
# [1000]	train-rmse:8.44867	valid-rmse:9.03738
# [1100]	train-rmse:8.35745	valid-rmse:8.97456
# [1200]	train-rmse:8.27931	valid-rmse:8.92527
# [1300]	train-rmse:8.20423	valid-rmse:8.89533
# [1400]	train-rmse:8.13711	valid-rmse:8.85120
# [1500]	train-rmse:8.07075	valid-rmse:8.82356
# [1600]	train-rmse:8.01396	valid-rmse:8.80536
# [1700]	train-rmse:7.96403	valid-rmse:8.80540
# [1800]	train-rmse:7.91327	valid-rmse:8.78309
# [1900]	train-rmse:7.86828	valid-rmse:8.78625
# [1922]	train-rmse:7.85698	valid-rmse:8.79121
# 3 0.01 0.5 0.25
# 0.6475163233116259
# [0]	train-rmse:12.15739	valid-rmse:12.40823
# [100]	train-rmse:10.78020	valid-rmse:11.09545
# [200]	train-rmse:10.09482	valid-rmse:10.41482
# [300]	train-rmse:9.66529	valid-rmse:9.98865
# [400]	train-rmse:9.34944	valid-rmse:9.70861
# [500]	train-rmse:9.11982	valid-rmse:9.51605
# [600]	train-rmse:8.92694	valid-rmse:9.36158
# [700]	train-rmse:8.76830	valid-rmse:9.22720
# [800]	train-rmse:8.63345	valid-rmse:9.13948
# [900]	train-rmse:8.52188	valid-rmse:9.07013
# [1000]	train-rmse:8.41235	valid-rmse:9.02482
# [1100]	train-rmse:8.32370	valid-rmse:8.97012
# [1200]	train-rmse:8.24577	valid-rmse:8.92711
# [1300]	train-rmse:8.17332	valid-rmse:8.89716
# [1400]	train-rmse:8.10742	valid-rmse:8.85948
# [1500]	train-rmse:8.04336	valid-rmse:8.83656
# [1600]	train-rmse:7.98452	valid-rmse:8.82475
# [1700]	train-rmse:7.93337	valid-rmse:8.81977
# [1800]	train-rmse:7.88163	valid-rmse:8.79621
# [1900]	train-rmse:7.83632	valid-rmse:8.80157
# [1919]	train-rmse:7.82745	valid-rmse:8.80364
# 3 0.01 0.5 0.3
# 0.6454335530566252
# [0]	train-rmse:12.16254	valid-rmse:12.41927
# [100]	train-rmse:10.91989	valid-rmse:11.22414
# [200]	train-rmse:10.18615	valid-rmse:10.52493
# [300]	train-rmse:9.73491	valid-rmse:10.09511
# [400]	train-rmse:9.43161	valid-rmse:9.81481
# [500]	train-rmse:9.20028	valid-rmse:9.62258
# [600]	train-rmse:9.01206	valid-rmse:9.47865
# [700]	train-rmse:8.85036	valid-rmse:9.34774
# [800]	train-rmse:8.71568	valid-rmse:9.25170
# [900]	train-rmse:8.59212	valid-rmse:9.15934
# [1000]	train-rmse:8.48724	valid-rmse:9.09844
# [1100]	train-rmse:8.39891	valid-rmse:9.04779
# [1200]	train-rmse:8.32064	valid-rmse:8.99099
# [1300]	train-rmse:8.25132	valid-rmse:8.96232
# [1400]	train-rmse:8.17934	valid-rmse:8.91175
# [1500]	train-rmse:8.11933	valid-rmse:8.88690
# [1600]	train-rmse:8.05972	valid-rmse:8.86069
# [1700]	train-rmse:8.01012	valid-rmse:8.84157
# [1800]	train-rmse:7.95593	valid-rmse:8.82384
# [1900]	train-rmse:7.90734	valid-rmse:8.81140
# [2000]	train-rmse:7.85858	valid-rmse:8.80306
# [2100]	train-rmse:7.81442	valid-rmse:8.79028
# [2200]	train-rmse:7.77577	valid-rmse:8.77588
# [2296]	train-rmse:7.74019	valid-rmse:8.77785
# 3 0.01 0.6 0.2
# 0.6469891232042267
# [0]	train-rmse:12.15745	valid-rmse:12.40845
# [100]	train-rmse:10.83411	valid-rmse:11.13077
# [200]	train-rmse:10.10860	valid-rmse:10.42938
# [300]	train-rmse:9.68169	valid-rmse:10.01157
# [400]	train-rmse:9.37880	valid-rmse:9.73582
# [500]	train-rmse:9.14496	valid-rmse:9.52930
# [600]	train-rmse:8.96061	valid-rmse:9.39512
# [700]	train-rmse:8.79447	valid-rmse:9.27077
# [800]	train-rmse:8.66031	valid-rmse:9.18404
# [900]	train-rmse:8.53777	valid-rmse:9.08857
# [1000]	train-rmse:8.43512	valid-rmse:9.03065
# [1100]	train-rmse:8.34638	valid-rmse:8.98056
# [1200]	train-rmse:8.26323	valid-rmse:8.92877
# [1300]	train-rmse:8.19100	valid-rmse:8.90072
# [1400]	train-rmse:8.12097	valid-rmse:8.85496
# [1500]	train-rmse:8.05809	valid-rmse:8.82580
# [1600]	train-rmse:8.00383	valid-rmse:8.80435
# [1700]	train-rmse:7.95716	valid-rmse:8.79683
# [1800]	train-rmse:7.90387	valid-rmse:8.78553
# [1900]	train-rmse:7.85895	valid-rmse:8.77760
# [2000]	train-rmse:7.81390	valid-rmse:8.77793
# [2100]	train-rmse:7.77015	valid-rmse:8.76727
# [2200]	train-rmse:7.73190	valid-rmse:8.75603
# [2300]	train-rmse:7.69353	valid-rmse:8.75129
# [2400]	train-rmse:7.65978	valid-rmse:8.75091
# [2500]	train-rmse:7.62641	valid-rmse:8.73502
# [2600]	train-rmse:7.59505	valid-rmse:8.72468
# [2700]	train-rmse:7.56158	valid-rmse:8.72013
# [2800]	train-rmse:7.52862	valid-rmse:8.71092
# [2900]	train-rmse:7.49655	valid-rmse:8.71512
# [2945]	train-rmse:7.48578	valid-rmse:8.71456
# 3 0.01 0.6 0.25
# 0.6577507344988351
# [0]	train-rmse:12.15680	valid-rmse:12.40777
# [100]	train-rmse:10.77944	valid-rmse:11.07527
# [200]	train-rmse:10.06608	valid-rmse:10.37494
# [300]	train-rmse:9.64944	valid-rmse:9.97232
# [400]	train-rmse:9.34553	valid-rmse:9.70495
# [500]	train-rmse:9.11596	valid-rmse:9.50778
# [600]	train-rmse:8.92213	valid-rmse:9.37630
# [700]	train-rmse:8.76548	valid-rmse:9.25762
# [800]	train-rmse:8.63244	valid-rmse:9.17651
# [900]	train-rmse:8.51629	valid-rmse:9.10611
# [1000]	train-rmse:8.41324	valid-rmse:9.04321
# [1100]	train-rmse:8.32514	valid-rmse:8.99747
# [1200]	train-rmse:8.24222	valid-rmse:8.94381
# [1300]	train-rmse:8.16803	valid-rmse:8.91935
# [1400]	train-rmse:8.09664	valid-rmse:8.87669
# [1500]	train-rmse:8.03440	valid-rmse:8.84397
# [1600]	train-rmse:7.97847	valid-rmse:8.83070
# [1700]	train-rmse:7.92818	valid-rmse:8.81371
# [1800]	train-rmse:7.87543	valid-rmse:8.79700
# [1900]	train-rmse:7.83156	valid-rmse:8.78427
# [2000]	train-rmse:7.78552	valid-rmse:8.78179
# [2100]	train-rmse:7.74272	valid-rmse:8.76901
# [2200]	train-rmse:7.70725	valid-rmse:8.75904
# [2269]	train-rmse:7.68185	valid-rmse:8.76477
# 3 0.01 0.6 0.3
# 0.6518149864860195
# [0]	train-rmse:12.16273	valid-rmse:12.41702
# [100]	train-rmse:10.90785	valid-rmse:11.20029
# [200]	train-rmse:10.17681	valid-rmse:10.50823
# [300]	train-rmse:9.72937	valid-rmse:10.07856
# [400]	train-rmse:9.42428	valid-rmse:9.79283
# [500]	train-rmse:9.19436	valid-rmse:9.59700
# [600]	train-rmse:9.00631	valid-rmse:9.44197
# [700]	train-rmse:8.84719	valid-rmse:9.32234
# [800]	train-rmse:8.71529	valid-rmse:9.23504
# [900]	train-rmse:8.59830	valid-rmse:9.15417
# [1000]	train-rmse:8.49783	valid-rmse:9.10495
# [1100]	train-rmse:8.40881	valid-rmse:9.04626
# [1200]	train-rmse:8.32302	valid-rmse:8.99039
# [1300]	train-rmse:8.24921	valid-rmse:8.95141
# [1400]	train-rmse:8.17911	valid-rmse:8.91086
# [1500]	train-rmse:8.11790	valid-rmse:8.88107
# [1600]	train-rmse:8.05454	valid-rmse:8.85868
# [1700]	train-rmse:8.00098	valid-rmse:8.84173
# [1800]	train-rmse:7.95039	valid-rmse:8.81658
# [1900]	train-rmse:7.90376	valid-rmse:8.80952
# [2000]	train-rmse:7.85538	valid-rmse:8.79503
# [2100]	train-rmse:7.81248	valid-rmse:8.78475
# [2200]	train-rmse:7.77386	valid-rmse:8.78150
# [2300]	train-rmse:7.73790	valid-rmse:8.77594
# [2400]	train-rmse:7.70151	valid-rmse:8.76211
# [2500]	train-rmse:7.66717	valid-rmse:8.74965
# [2600]	train-rmse:7.63154	valid-rmse:8.74317
# [2700]	train-rmse:7.59526	valid-rmse:8.73483
# ...
# 5 0.005 0.5 0.2
# 0.6629299923422852
# [0]	train-rmse:12.16300	valid-rmse:12.42026
# [100]	train-rmse:10.96468	valid-rmse:11.32049
# [200]	train-rmse:10.14653	valid-rmse:10.58227
# [300]	train-rmse:9.58568	valid-rmse:10.07651
# [400]	train-rmse:9.19892	valid-rmse:9.73717
# [500]	train-rmse:8.90780	valid-rmse:9.49863
# [600]	train-rmse:8.68824	valid-rmse:9.34010
# [700]	train-rmse:8.51363	valid-rmse:9.20189
# [800]	train-rmse:8.36907	valid-rmse:9.10714
# [900]	train-rmse:8.24353	valid-rmse:9.01569
# [1000]	train-rmse:8.13072	valid-rmse:8.95508
# [1100]	train-rmse:8.03654	valid-rmse:8.89861
# [1200]	train-rmse:7.95047	valid-rmse:8.84897
# [1300]	train-rmse:7.87829	valid-rmse:8.82222
# [1400]	train-rmse:7.80869	valid-rmse:8.79082
# [1500]	train-rmse:7.74369	valid-rmse:8.77394
# [1600]	train-rmse:7.68513	valid-rmse:8.75804
# [1700]	train-rmse:7.63348	valid-rmse:8.74956
# [1800]	train-rmse:7.58220	valid-rmse:8.73537
# [1900]	train-rmse:7.53625	valid-rmse:8.73043
# [2000]	train-rmse:7.48829	valid-rmse:8.72308
# [2100]	train-rmse:7.44449	valid-rmse:8.71561
# [2200]	train-rmse:7.41028	valid-rmse:8.70836
# [2300]	train-rmse:7.37102	valid-rmse:8.70213
# [2400]	train-rmse:7.33588	valid-rmse:8.69726
# [2500]	train-rmse:7.30040	valid-rmse:8.68614
# [2600]	train-rmse:7.26730	valid-rmse:8.68408
# [2682]	train-rmse:7.23882	valid-rmse:8.68576
# 5 0.005 0.5 0.25
# 0.6642180939459327
# [0]	train-rmse:12.16285	valid-rmse:12.42018
# [100]	train-rmse:10.89253	valid-rmse:11.27320
# [200]	train-rmse:10.07287	valid-rmse:10.53705
# [300]	train-rmse:9.52293	valid-rmse:10.05290
# [400]	train-rmse:9.13520	valid-rmse:9.70919
# [500]	train-rmse:8.85511	valid-rmse:9.47927
# [600]	train-rmse:8.63415	valid-rmse:9.32536
# [700]	train-rmse:8.46559	valid-rmse:9.19582
# [800]	train-rmse:8.32105	valid-rmse:9.10984
# [900]	train-rmse:8.19946	valid-rmse:9.03346
# [1000]	train-rmse:8.08978	valid-rmse:8.97829
# [1100]	train-rmse:7.99730	valid-rmse:8.92961
# [1200]	train-rmse:7.91443	valid-rmse:8.88581
# [1300]	train-rmse:7.84620	valid-rmse:8.85773
# [1400]	train-rmse:7.77750	valid-rmse:8.82174
# [1500]	train-rmse:7.71339	valid-rmse:8.80387
# [1600]	train-rmse:7.65535	valid-rmse:8.78897
# [1700]	train-rmse:7.60310	valid-rmse:8.77692
# [1800]	train-rmse:7.55182	valid-rmse:8.76189
# [1900]	train-rmse:7.50420	valid-rmse:8.75877
# [1980]	train-rmse:7.46465	valid-rmse:8.75938
# 5 0.005 0.5 0.3
# 0.654071994076895
# [0]	train-rmse:12.16602	valid-rmse:12.42287
# [100]	train-rmse:11.03961	valid-rmse:11.38908
# [200]	train-rmse:10.24706	valid-rmse:10.67675
# [300]	train-rmse:9.68180	valid-rmse:10.17870
# [400]	train-rmse:9.29133	valid-rmse:9.84800
# [500]	train-rmse:8.98640	valid-rmse:9.60776
# [600]	train-rmse:8.75879	valid-rmse:9.42777
# [700]	train-rmse:8.57284	valid-rmse:9.29541
# [800]	train-rmse:8.42042	valid-rmse:9.19801
# [900]	train-rmse:8.28381	valid-rmse:9.09974
# [1000]	train-rmse:8.17527	valid-rmse:9.04314
# [1100]	train-rmse:8.08022	valid-rmse:9.00060
# [1200]	train-rmse:7.99446	valid-rmse:8.94693
# [1300]	train-rmse:7.91630	valid-rmse:8.91893
# [1400]	train-rmse:7.84230	valid-rmse:8.88108
# [1500]	train-rmse:7.77704	valid-rmse:8.85382
# [1600]	train-rmse:7.71659	valid-rmse:8.82551
# [1700]	train-rmse:7.66240	valid-rmse:8.80874
# [1800]	train-rmse:7.61201	valid-rmse:8.79696
# [1900]	train-rmse:7.56346	valid-rmse:8.78227
# [2000]	train-rmse:7.51592	valid-rmse:8.77559
# [2100]	train-rmse:7.47217	valid-rmse:8.76313
# [2200]	train-rmse:7.43477	valid-rmse:8.75749
# [2300]	train-rmse:7.39773	valid-rmse:8.75657
# [2400]	train-rmse:7.35909	valid-rmse:8.75061
# [2500]	train-rmse:7.32319	valid-rmse:8.73721
# [2600]	train-rmse:7.29012	valid-rmse:8.73324
# [2700]	train-rmse:7.25404	valid-rmse:8.72520
# [2800]	train-rmse:7.22189	valid-rmse:8.72177
# [2900]	train-rmse:7.18842	valid-rmse:8.71916
# [2949]	train-rmse:7.17536	valid-rmse:8.72083
# 5 0.005 0.6 0.2
# 0.6640874116764084
# [0]	train-rmse:12.16304	valid-rmse:12.42062
# [100]	train-rmse:10.95958	valid-rmse:11.32025
# [200]	train-rmse:10.13352	valid-rmse:10.57949
# [300]	train-rmse:9.56976	valid-rmse:10.07420
# [400]	train-rmse:9.17784	valid-rmse:9.74160
# [500]	train-rmse:8.89120	valid-rmse:9.50571
# [600]	train-rmse:8.66428	valid-rmse:9.33526
# [700]	train-rmse:8.48644	valid-rmse:9.20831
# [800]	train-rmse:8.33790	valid-rmse:9.11867
# [900]	train-rmse:8.21269	valid-rmse:9.03041
# [1000]	train-rmse:8.10340	valid-rmse:8.97464
# [1100]	train-rmse:8.00888	valid-rmse:8.93060
# [1200]	train-rmse:7.92284	valid-rmse:8.88863
# [1300]	train-rmse:7.84885	valid-rmse:8.86541
# [1400]	train-rmse:7.77994	valid-rmse:8.83322
# [1500]	train-rmse:7.71645	valid-rmse:8.81211
# [1600]	train-rmse:7.65798	valid-rmse:8.78837
# [1700]	train-rmse:7.60897	valid-rmse:8.77912
# [1800]	train-rmse:7.55829	valid-rmse:8.76883
# [1900]	train-rmse:7.51335	valid-rmse:8.76037
# [2000]	train-rmse:7.46714	valid-rmse:8.76017
# [2100]	train-rmse:7.42489	valid-rmse:8.75269
# [2200]	train-rmse:7.38837	valid-rmse:8.74663
# [2300]	train-rmse:7.35103	valid-rmse:8.74820
# [2400]	train-rmse:7.31491	valid-rmse:8.74510
# [2500]	train-rmse:7.27901	valid-rmse:8.73398
# [2600]	train-rmse:7.24444	valid-rmse:8.73428
# [2700]	train-rmse:7.21002	valid-rmse:8.73193
# [2726]	train-rmse:7.20203	valid-rmse:8.73024
# 5 0.005 0.6 0.25
# 0.6643294853970632
# [0]	train-rmse:12.16269	valid-rmse:12.41955
# [100]	train-rmse:10.87335	valid-rmse:11.25032
# [200]	train-rmse:10.05620	valid-rmse:10.51621
# [300]	train-rmse:9.49926	valid-rmse:10.02378
# [400]	train-rmse:9.09889	valid-rmse:9.68422
# [500]	train-rmse:8.82026	valid-rmse:9.45944
# [600]	train-rmse:8.60241	valid-rmse:9.30487
# [700]	train-rmse:8.43624	valid-rmse:9.18935
# [800]	train-rmse:8.29341	valid-rmse:9.10577
# [900]	train-rmse:8.17236	valid-rmse:9.03355
# [1000]	train-rmse:8.06477	valid-rmse:8.97412
# [1100]	train-rmse:7.97266	valid-rmse:8.93659
# [1200]	train-rmse:7.88980	valid-rmse:8.89858
# [1300]	train-rmse:7.82001	valid-rmse:8.87760
# [1400]	train-rmse:7.75035	valid-rmse:8.84764
# [1500]	train-rmse:7.68623	valid-rmse:8.82836
# [1600]	train-rmse:7.62819	valid-rmse:8.81040
# [1700]	train-rmse:7.57690	valid-rmse:8.79819
# [1800]	train-rmse:7.52701	valid-rmse:8.78817
# [1900]	train-rmse:7.48095	valid-rmse:8.77692
# [2000]	train-rmse:7.43634	valid-rmse:8.77458
# [2100]	train-rmse:7.39445	valid-rmse:8.76950
# [2200]	train-rmse:7.35842	valid-rmse:8.76440
# [2300]	train-rmse:7.32145	valid-rmse:8.77159
# [2347]	train-rmse:7.30562	valid-rmse:8.77077
# 5 0.005 0.6 0.3
# 0.6588221552649225
# [0]	train-rmse:12.16714	valid-rmse:12.42353
# [100]	train-rmse:11.03256	valid-rmse:11.38615
# [200]	train-rmse:10.22444	valid-rmse:10.66582
# [300]	train-rmse:9.66214	valid-rmse:10.17442
# [400]	train-rmse:9.25621	valid-rmse:9.83723
# [500]	train-rmse:8.95507	valid-rmse:9.60429
# [600]	train-rmse:8.72628	valid-rmse:9.43057
# [700]	train-rmse:8.54006	valid-rmse:9.29669
# [800]	train-rmse:8.39048	valid-rmse:9.19161
# [900]	train-rmse:8.26043	valid-rmse:9.10236
# [1000]	train-rmse:8.15262	valid-rmse:9.04738
# [1100]	train-rmse:8.05621	valid-rmse:8.99556
# [1200]	train-rmse:7.96848	valid-rmse:8.94368
# [1300]	train-rmse:7.89239	valid-rmse:8.91387
# [1400]	train-rmse:7.82248	valid-rmse:8.87688
# [1500]	train-rmse:7.76007	valid-rmse:8.85657
# [1600]	train-rmse:7.69658	valid-rmse:8.83220
# [1700]	train-rmse:7.64296	valid-rmse:8.81606
# [1800]	train-rmse:7.59171	valid-rmse:8.80020
# [1900]	train-rmse:7.54677	valid-rmse:8.79377
# [2000]	train-rmse:7.49974	valid-rmse:8.77988
# [2100]	train-rmse:7.45803	valid-rmse:8.77271
# [2200]	train-rmse:7.42124	valid-rmse:8.76909
# [2290]	train-rmse:7.38963	valid-rmse:8.76697
# 5 0.005 0.7 0.2
# 0.6556876086916719
# [0]	train-rmse:12.16284	valid-rmse:12.41925
# [100]	train-rmse:10.94864	valid-rmse:11.30297
# [200]	train-rmse:10.12437	valid-rmse:10.55869
# [300]	train-rmse:9.55724	valid-rmse:10.07355
# [400]	train-rmse:9.15914	valid-rmse:9.74092
# [500]	train-rmse:8.86124	valid-rmse:9.50957
# [600]	train-rmse:8.64233	valid-rmse:9.34663
# [700]	train-rmse:8.46542	valid-rmse:9.21920
# [800]	train-rmse:8.32372	valid-rmse:9.13550
# [900]	train-rmse:8.19957	valid-rmse:9.05976
# [1000]	train-rmse:8.09338	valid-rmse:9.01357
# [1100]	train-rmse:7.99838	valid-rmse:8.95969
# [1200]	train-rmse:7.91578	valid-rmse:8.91614
# [1300]	train-rmse:7.84476	valid-rmse:8.89161
# [1400]	train-rmse:7.77445	valid-rmse:8.85942
# [1500]	train-rmse:7.71027	valid-rmse:8.84211
# [1600]	train-rmse:7.64866	valid-rmse:8.82374
# [1700]	train-rmse:7.59384	valid-rmse:8.81269
# [1800]	train-rmse:7.54281	valid-rmse:8.79458
# [1900]	train-rmse:7.49880	valid-rmse:8.79341
# [2000]	train-rmse:7.45496	valid-rmse:8.78723
# [2100]	train-rmse:7.41140	valid-rmse:8.78221
# [2200]	train-rmse:7.37615	valid-rmse:8.78191
# [2266]	train-rmse:7.35197	valid-rmse:8.78282
# 5 0.005 0.7 0.25
# 0.6574966881897868
# [0]	train-rmse:12.16263	valid-rmse:12.41816
# [100]	train-rmse:10.85642	valid-rmse:11.24180
# [200]	train-rmse:10.03624	valid-rmse:10.50181
# [300]	train-rmse:9.47707	valid-rmse:10.02137
# [400]	train-rmse:9.07794	valid-rmse:9.68840
# [500]	train-rmse:8.79823	valid-rmse:9.46300
# [600]	train-rmse:8.58542	valid-rmse:9.31509
# [700]	train-rmse:8.41976	valid-rmse:9.20184
# [800]	train-rmse:8.28371	valid-rmse:9.13198
# [900]	train-rmse:8.16205	valid-rmse:9.06377
# [1000]	train-rmse:8.05536	valid-rmse:9.01365
# [1100]	train-rmse:7.96113	valid-rmse:8.96483
# [1200]	train-rmse:7.88051	valid-rmse:8.92381
# [1300]	train-rmse:7.80894	valid-rmse:8.89875
# [1400]	train-rmse:7.73592	valid-rmse:8.86640
# [1500]	train-rmse:7.67334	valid-rmse:8.84727
# [1600]	train-rmse:7.61143	valid-rmse:8.82512
# [1700]	train-rmse:7.55975	valid-rmse:8.81533
# [1800]	train-rmse:7.51212	valid-rmse:8.80201
# [1900]	train-rmse:7.46662	valid-rmse:8.80102
# [2000]	train-rmse:7.42090	valid-rmse:8.79671
# [2100]	train-rmse:7.38004	valid-rmse:8.79019
# [2200]	train-rmse:7.34732	valid-rmse:8.79329
# 5 0.005 0.7 0.3
# 0.6574176058806276
# [0]	train-rmse:12.14848	valid-rmse:12.41051
# [100]	train-rmse:10.29293	valid-rmse:10.73113
# [200]	train-rmse:9.33952	valid-rmse:9.90545
# [300]	train-rmse:8.78918	valid-rmse:9.43677
# [400]	train-rmse:8.46221	valid-rmse:9.18809
# [500]	train-rmse:8.21251	valid-rmse:9.04654
# [600]	train-rmse:8.02210	valid-rmse:8.95186
# [700]	train-rmse:7.87758	valid-rmse:8.87184
# [800]	train-rmse:7.75931	valid-rmse:8.82895
# [900]	train-rmse:7.65541	valid-rmse:8.79759
# [1000]	train-rmse:7.55332	valid-rmse:8.77733
# [1100]	train-rmse:7.46662	valid-rmse:8.76393
# [1200]	train-rmse:7.39410	valid-rmse:8.74658
# [1300]	train-rmse:7.32768	valid-rmse:8.75507
# [1337]	train-rmse:7.30248	valid-rmse:8.74458
# 5 0.01 0.5 0.2
# 0.6592232210405454
# [0]	train-rmse:12.14208	valid-rmse:12.40376
# [100]	train-rmse:10.15990	valid-rmse:10.59228
# [200]	train-rmse:9.21640	valid-rmse:9.76990
# [300]	train-rmse:8.70324	valid-rmse:9.35251
# [400]	train-rmse:8.38328	valid-rmse:9.11978
# [500]	train-rmse:8.14595	valid-rmse:8.97721
# [600]	train-rmse:7.96436	valid-rmse:8.89737
# [700]	train-rmse:7.82649	valid-rmse:8.84075
# [800]	train-rmse:7.70466	valid-rmse:8.80142
# [900]	train-rmse:7.60293	valid-rmse:8.77045
# [1000]	train-rmse:7.50469	valid-rmse:8.75699
# [1100]	train-rmse:7.42020	valid-rmse:8.73068
# [1200]	train-rmse:7.34588	valid-rmse:8.70622
# [1300]	train-rmse:7.27912	valid-rmse:8.71224
# [1337]	train-rmse:7.25306	valid-rmse:8.70648
# 5 0.01 0.5 0.25
# 0.665643344029272
# [0]	train-rmse:12.14177	valid-rmse:12.40361
# [100]	train-rmse:10.04520	valid-rmse:10.52838
# [200]	train-rmse:9.13219	valid-rmse:9.72527
# [300]	train-rmse:8.64689	valid-rmse:9.34242
# [400]	train-rmse:8.32298	valid-rmse:9.10358
# [500]	train-rmse:8.10260	valid-rmse:8.97717
# [600]	train-rmse:7.92163	valid-rmse:8.91557
# [700]	train-rmse:7.78989	valid-rmse:8.86536
# [800]	train-rmse:7.67138	valid-rmse:8.82838
# [900]	train-rmse:7.56885	valid-rmse:8.80649
# [1000]	train-rmse:7.47506	valid-rmse:8.79382
# [1100]	train-rmse:7.39071	valid-rmse:8.77394
# [1200]	train-rmse:7.32033	valid-rmse:8.75871
# [1300]	train-rmse:7.25291	valid-rmse:8.76837
# [1324]	train-rmse:7.23777	valid-rmse:8.77270
# 5 0.01 0.5 0.3
# 0.6595543201140084
# [0]	train-rmse:12.14810	valid-rmse:12.40898
# [100]	train-rmse:10.24953	valid-rmse:10.68702
# [200]	train-rmse:9.28694	valid-rmse:9.86297
# [300]	train-rmse:8.74428	valid-rmse:9.41763
# [400]	train-rmse:8.41925	valid-rmse:9.19213
# [500]	train-rmse:8.17427	valid-rmse:9.04576
# [600]	train-rmse:7.98803	valid-rmse:8.95507
# [700]	train-rmse:7.83829	valid-rmse:8.88119
# [800]	train-rmse:7.71781	valid-rmse:8.83232
# [900]	train-rmse:7.61233	valid-rmse:8.79036
# [1000]	train-rmse:7.51901	valid-rmse:8.78262
# [1100]	train-rmse:7.43315	valid-rmse:8.75988
# [1200]	train-rmse:7.36324	valid-rmse:8.74486
# [1300]	train-rmse:7.29651	valid-rmse:8.74221
# [1336]	train-rmse:7.27060	valid-rmse:8.73468
# 5 0.01 0.6 0.2
# 0.6640049255279556
# [0]	train-rmse:12.14215	valid-rmse:12.40448
# [100]	train-rmse:10.14601	valid-rmse:10.58933
# [200]	train-rmse:9.19517	valid-rmse:9.78744
# [300]	train-rmse:8.68063	valid-rmse:9.38249
# [400]	train-rmse:8.35567	valid-rmse:9.15732
# [500]	train-rmse:8.12263	valid-rmse:9.02109
# [600]	train-rmse:7.94027	valid-rmse:8.94639
# [700]	train-rmse:7.79402	valid-rmse:8.88574
# [800]	train-rmse:7.66426	valid-rmse:8.83453
# [900]	train-rmse:7.56089	valid-rmse:8.79759
# [1000]	train-rmse:7.46779	valid-rmse:8.78532
# [1100]	train-rmse:7.38418	valid-rmse:8.75986
# [1200]	train-rmse:7.30805	valid-rmse:8.74375
# [1300]	train-rmse:7.24147	valid-rmse:8.74383
# [1337]	train-rmse:7.21485	valid-rmse:8.73660
# 5 0.01 0.6 0.25
# 0.665148961911816
# [0]	train-rmse:12.14146	valid-rmse:12.40235
# [100]	train-rmse:10.02102	valid-rmse:10.48925
# [200]	train-rmse:9.09955	valid-rmse:9.70297
# [300]	train-rmse:8.62303	valid-rmse:9.34033
# [400]	train-rmse:8.29980	valid-rmse:9.12742
# [500]	train-rmse:8.07888	valid-rmse:9.00042
# [600]	train-rmse:7.90599	valid-rmse:8.93405
# [700]	train-rmse:7.76299	valid-rmse:8.88937
# [800]	train-rmse:7.63731	valid-rmse:8.83913
# [900]	train-rmse:7.53196	valid-rmse:8.80478
# [1000]	train-rmse:7.43951	valid-rmse:8.79777
# [1100]	train-rmse:7.35975	valid-rmse:8.78254
# [1200]	train-rmse:7.28669	valid-rmse:8.77051
# [1300]	train-rmse:7.22155	valid-rmse:8.77167
# [1400]	train-rmse:7.15828	valid-rmse:8.75489
# [1500]	train-rmse:7.10157	valid-rmse:8.76135
# [1600]	train-rmse:7.04806	valid-rmse:8.76028
# [1673]	train-rmse:7.01136	valid-rmse:8.76077
# 5 0.01 0.6 0.3
# 0.669753380868632
# [0]	train-rmse:12.15034	valid-rmse:12.41029
# [100]	train-rmse:10.24754	valid-rmse:10.67803
# [200]	train-rmse:9.28081	valid-rmse:9.86027
# [300]	train-rmse:8.73836	valid-rmse:9.42130
# [400]	train-rmse:8.40386	valid-rmse:9.18707
# [500]	train-rmse:8.16255	valid-rmse:9.05013
# [600]	train-rmse:7.97657	valid-rmse:8.96218
# [700]	train-rmse:7.82698	valid-rmse:8.88859
# [800]	train-rmse:7.70838	valid-rmse:8.85048
# [900]	train-rmse:7.60499	valid-rmse:8.82057
# [1000]	train-rmse:7.50909	valid-rmse:8.80567
# [1100]	train-rmse:7.41903	valid-rmse:8.77727
# [1200]	train-rmse:7.34555	valid-rmse:8.75668
# [1300]	train-rmse:7.27345	valid-rmse:8.75592
# [1337]	train-rmse:7.24901	valid-rmse:8.75072
# 5 0.01 0.7 0.2
# 0.6589729298358494
# [0]	train-rmse:12.14175	valid-rmse:12.40175
# [100]	train-rmse:10.13672	valid-rmse:10.57901
# [200]	train-rmse:9.17837	valid-rmse:9.75066
# [300]	train-rmse:8.66358	valid-rmse:9.36266
# [400]	train-rmse:8.33806	valid-rmse:9.14708
# [500]	train-rmse:8.10983	valid-rmse:9.01515
# [600]	train-rmse:7.93182	valid-rmse:8.93513
# [700]	train-rmse:7.79026	valid-rmse:8.88840
# [800]	train-rmse:7.67116	valid-rmse:8.85567
# [900]	train-rmse:7.56676	valid-rmse:8.83136
# [1000]	train-rmse:7.47363	valid-rmse:8.82425
# [1100]	train-rmse:7.38587	valid-rmse:8.80490
# [1200]	train-rmse:7.30810	valid-rmse:8.78996
# [1300]	train-rmse:7.23636	valid-rmse:8.78923
# [1400]	train-rmse:7.17308	valid-rmse:8.77736
# [1500]	train-rmse:7.11381	valid-rmse:8.78633
# 5 0.01 0.7 0.25
# 0.6636881087031297
# [0]	train-rmse:12.14133	valid-rmse:12.39956
# [100]	train-rmse:10.00726	valid-rmse:10.50210
# [200]	train-rmse:9.07165	valid-rmse:9.72753
# [300]	train-rmse:8.58573	valid-rmse:9.37236
# [400]	train-rmse:8.26860	valid-rmse:9.16857
# [500]	train-rmse:8.05110	valid-rmse:9.03785
# [600]	train-rmse:7.88533	valid-rmse:8.96629
# [700]	train-rmse:7.74527	valid-rmse:8.92315
# [800]	train-rmse:7.62680	valid-rmse:8.89515
# [900]	train-rmse:7.52507	valid-rmse:8.88392
# [1000]	train-rmse:7.43118	valid-rmse:8.87334
# [1100]	train-rmse:7.35169	valid-rmse:8.86181
# [1200]	train-rmse:7.27506	valid-rmse:8.84708
# [1300]	train-rmse:7.20740	valid-rmse:8.84694
# [1337]	train-rmse:7.18142	valid-rmse:8.84370
# 5 0.01 0.7 0.3
# 0.6591797527022162

# %%
index
# Out:
# [5, 0.01, 0.6, 0.3]

# %%
pred=m2.predict(dtest)
seq_id = []
tm = []
for i in range(len(pred)):
    seq_id.append(31390+i)
    tm.append(pred[i])
data = {
    "seq_id":seq_id,
    "tm":tm
}
df = pd.DataFrame(data)
df.to_csv("submission.csv")

# %%
#### Generating the design matrix of training data and validation data
#### The validation data are classified based on the group number.
group_num = max(cdata['group'])
valid_size = 0
valid_index=np.array(random.sample(range(0, group_num+1), int(group_num*0.3)))
train_index = np.array(range(0,group_num+1))
train_index = np.delete(train_index,valid_index)
X1_train = pd.DataFrame()
X2_train = pd.DataFrame()
X1_valid = pd.DataFrame()
X2_valid = pd.DataFrame()
train_y = np.array([])
valid_y = np.array([])
y = np.array([])
for i in range(0,group_num+1):
    group_data = cdata[cdata['group']==i]
    g_seq = group_data['protein_sequence']
    g_seq = np.array(g_seq)
    g_y = group_data['tm']
    g_y = np.array(g_y)
    wt_index = get_wt_sup(g_seq)
    g_y = g_y - g_y[wt_index]
    y = np.append(y, g_y)
    wt = g_seq[wt_index]
    if (i in train_index):
        for k in g_seq:
            freq = find_mutation(wt,k)
            df = pd.DataFrame(freq,index=[1])
            X1_train = pd.concat([X1_train,df],ignore_index = True)
            x = find_mut_pst(wt, k)
            freq2 = get_nba(x, wt)
            dff = pd.DataFrame(freq2, index=[1])
            X2_train = pd.concat([X2_train,dff], ignore_index = True)
        train_y = np.append(train_y, g_y)
    else:
        for k in g_seq:
            freq = find_mutation(wt,k)
            df = pd.DataFrame(freq,index=[1])
            X1_valid = pd.concat([X1_valid,df],ignore_index = True)
            x = find_mut_pst(wt, k)
            freq2 = get_nba(x, wt)
            dff = pd.DataFrame(freq2, index=[1])
            X2_valid = pd.concat([X2_valid,dff], ignore_index = True)
        valid_y = np.append(valid_y, g_y)
X1_train = X1_train.fillna(0)
X2_train = X2_train.fillna(0)
X1_valid = X1_valid.fillna(0)
X2_valid = X2_valid.fillna(0)
train_X = pd.concat([X1_train,X2_train],axis = 1)
valid_X = pd.concat([X1_valid,X2_valid],axis = 1)
train_y = pd.DataFrame(train_y)
valid_y = pd.DataFrame(valid_y)

# %%
####Ensuring design matrix(features) of training and test data have the same size.
check_1 = pd.concat([train_X, valid_X],ignore_index = True).fillna(0)
check_2 = pd.concat([check_1, test_design], ignore_index = True).fillna(0)
dim1 = train_X.shape[0]
dim2 = valid_X.shape[0]
dim3 = check_2.shape[0]
train_X = check_2.iloc[0:dim1]
valid_X = check_2.iloc[dim1:dim1+dim2]
test_design = check_2.iloc[dim1+dim2:dim3]
train_X.to_csv('train_X.csv')
train_y.to_csv('train_y.csv')

# %%
# Model (2) This model has a validation set that only contains enzymes 
# with completely different wildtypes from wildtypes of the training set
xgb_parms = { 
    'max_depth':4, 
    'learning_rate':0.001, 
    'subsample':0.5,
    'colsample_bytree':0.2, 
    'eval_metric':'rmse',
    'objective':'reg:squarederror',
    'random_state':123,
    "reg_lambda":0.1
}

model = xgb
dtrain = xgb.DMatrix(data=train_X, label=train_y)
dvalid = xgb.DMatrix(data=valid_X, label=valid_y)
dtest = xgb.DMatrix(data=test_design)
m3 = xgb.train(xgb_parms, dtrain=dtrain,evals=[(dtrain,"train"),(dvalid, "valid")],
                 num_boost_round=10000,
                 early_stopping_rounds = 100,
                 verbose_eval = 100)

# %%
####Neural network (A neural network Model)
####This model did not perform well.

import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
tX1 = torch.tensor(train_X.values)
tdm = torch.tensor(test_X.values)
ty = torch.tensor(y)
X_train, X_test, y_train, y_test = train_test_split(tX1, ty, test_size=0.1, random_state=123)


n_input, n_hidden, n_out, batch_size, learning_rate = 406, 83, 1, 100, 0.1
model = nn.Sequential(nn.Linear(n_input, n_hidden),
                      nn.ReLU(),
                      nn.Linear(n_hidden, 64),
                      nn.ReLU(),
                      nn.Linear(64, 16),
                      nn.ReLU(),
                      nn.Linear(16,4),
                      nn.ReLU(),
                      nn.Linear(4, n_out),
                      nn.Sigmoid())

print(model)
model.double()
loss_function = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
losses = []
mlos = []
for epoch in range(1000):
    print(epoch)
    pred_y = model(X_train)
    pred_yy = model(X_test).float()
    loss = loss_function(pred_y, y_train)
    mloss = loss_function(pred_yy, y_test)
    losses.append(loss.item())
    mlos.append(mloss.item())
    model.zero_grad()
    loss.backward()

    optimizer.step()
